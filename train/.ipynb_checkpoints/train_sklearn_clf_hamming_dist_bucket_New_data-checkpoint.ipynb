# %%
import numpy as np
import pandas as pd
import warnings
import csv
from itertools import groupby

from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import RidgeClassifierCV
from sklearn.neighbors import NearestCentroid
from sklearn.linear_model import RidgeClassifier

from sklearn.metrics import recall_score as rec, precision_score as pre, f1_score as f1, accuracy_score as acc

# %%
# Read Signatures and z scores
csv_name = "../data/labeled_sigs"
csv_name = "../data/Adomain_Substrate_labeled_sigs.report"
z_score_csv_name = "../data/z_score_aa"
df_original = pd.read_csv(csv_name, delimiter='\t')
z_scores_df = pd.read_csv(z_score_csv_name, delimiter=' ')

# %%
# Prep for hardcoded values
m=26
nrow = 12
D = np.zeros((nrow, m))
D1 = D[0 ,:]
D2 = D[1 ,:]
D3 = D[2 ,:]
D4 = D[3 ,:]
D5 = D[4 ,:]
D6 = D[5 ,:]
D7 = D[6 ,:]
D8 = D[7 ,:]
D9 = D[8 ,:]
D10 = D[9 ,:]
D11 = D[10 ,:]
D12 = D[11 ,:]

# %%
# Hard coded values, taken from NRPSPredictor2 github

#1 aa-alpha-helix.aaindex
D1[0]=1.420;D1[1]=0.000;D1[2]=0.700;D1[3]=1.010;D1[4]=1.510;D1[5]=1.130;D1[6]=0.570;D1[7]=1.000;D1[8]=1.080;D1[9]=0.000;D1[10]=1.160;D1[11]=1.210;D1[12]=1.450;D1[13]=0.670;D1[14]=0.000;D1[15]=0.570;D1[16]=1.110;D1[17]=0.980;D1[18]=0.770;D1[19]=0.830;D1[20]=0.000;D1[21]=1.060;D1[22]=1.080;D1[23]=0.000;D1[24]=0.690;D1[25]=0.000;
#2 aa-beta-sheet.aaindex
D2[0]=0.830;D2[1]=0.000;D2[2]=1.190;D2[3]=0.540;D2[4]=0.370;D2[5]=1.380;D2[6]=0.750;D2[7]=0.870;D2[8]=1.600;D2[9]=0.000;D2[10]=0.740;D2[11]=1.300;D2[12]=1.050;D2[13]=0.890;D2[14]=0.000;D2[15]=0.550;D2[16]=1.100;D2[17]=0.930;D2[18]=0.750;D2[19]=1.190;D2[20]=0.000;D2[21]=1.700;D2[22]=1.370;D2[23]=0.000;D2[24]=1.470;D2[25]=0.000;
#3 aa-beta-turn.aaindex
D3[0]=0.740;D3[1]=0.000;D3[2]=0.960;D3[3]=1.520;D3[4]=0.950;D3[5]=0.660;D3[6]=1.560;D3[7]=0.950;D3[8]=0.470;D3[9]=0.000;D3[10]=1.190;D3[11]=0.500;D3[12]=0.600;D3[13]=1.460;D3[14]=0.000;D3[15]=1.560;D3[16]=0.960;D3[17]=1.010;D3[18]=1.430;D3[19]=0.980;D3[20]=0.000;D3[21]=0.590;D3[22]=0.600;D3[23]=0.000;D3[24]=1.140;D3[25]=0.000;
#4 aa-hydrogenbond.aaindex
D4[0]=0.000;D4[1]=0.000;D4[2]=0.000;D4[3]=1.000;D4[4]=1.000;D4[5]=0.000;D4[6]=0.000;D4[7]=1.000;D4[8]=0.000;D4[9]=0.000;D4[10]=2.000;D4[11]=0.000;D4[12]=0.000;D4[13]=2.000;D4[14]=0.000;D4[15]=0.000;D4[16]=2.000;D4[17]=4.000;D4[18]=1.000;D4[19]=1.000;D4[20]=0.000;D4[21]=0.000;D4[22]=1.000;D4[23]=0.000;D4[24]=1.000;D4[25]=0.000;
#5 aa-hydrophobicity-neu1.aaindex
D5[0]=0.060;D5[1]=0.000;D5[2]=-0.560;D5[3]=0.970;D5[4]=0.850;D5[5]=-0.990;D5[6]=0.320;D5[7]=0.150;D5[8]=-1.000;D5[9]=0.000;D5[10]=1.000;D5[11]=-0.830;D5[12]=-0.680;D5[13]=0.700;D5[14]=0.000;D5[15]=0.450;D5[16]=0.710;D5[17]=0.800;D5[18]=0.480;D5[19]=0.380;D5[20]=0.000;D5[21]=-0.750;D5[22]=-0.570;D5[23]=0.000;D5[24]=-0.350;D5[25]=0.000;
#6 aa-hydrophobicity-neu2.aaindex
D6[0]=-0.250;D6[1]=0.000;D6[2]=-0.400;D6[3]=-0.080;D6[4]=-0.100;D6[5]=0.180;D6[6]=-0.320;D6[7]=-0.030;D6[8]=-0.030;D6[9]=0.000;D6[10]=0.320;D6[11]=0.050;D6[12]=-0.010;D6[13]=-0.060;D6[14]=0.000;D6[15]=0.230;D6[16]=-0.020;D6[17]=0.190;D6[18]=-0.150;D6[19]=-0.100;D6[20]=0.000;D6[21]=-0.190;D6[22]=0.310;D6[23]=0.000;D6[24]=0.400;D6[25]=0.000;
#7 aa-hydrophobicity-neu3.aaindex
D7[0]=0.250;D7[1]=0.000;D7[2]=-0.140;D7[3]=0.080;D7[4]=-0.050;D7[5]=0.150;D7[6]=0.280;D7[7]=-0.100;D7[8]=0.100;D7[9]=0.000;D7[10]=0.110;D7[11]=0.010;D7[12]=0.040;D7[13]=0.170;D7[14]=0.000;D7[15]=0.410;D7[16]=0.120;D7[17]=-0.410;D7[18]=0.230;D7[19]=0.290;D7[20]=0.000;D7[21]=0.030;D7[22]=0.340;D7[23]=0.000;D7[24]=-0.020;D7[25]=0.000;
#8 aa-isoelectric.aaindex
D8[0]=6.000;D8[1]=0.000;D8[2]=5.050;D8[3]=2.770;D8[4]=3.220;D8[5]=5.480;D8[6]=5.970;D8[7]=7.590;D8[8]=6.020;D8[9]=0.000;D8[10]=9.740;D8[11]=5.980;D8[12]=5.740;D8[13]=5.410;D8[14]=0.000;D8[15]=6.300;D8[16]=5.650;D8[17]=10.760;D8[18]=5.680;D8[19]=5.660;D8[20]=0.000;D8[21]=5.960;D8[22]=5.890;D8[23]=0.000;D8[24]=5.660;D8[25]=0.000;
#9 aa-polar-grantham.aaindex
D9[0]=8.100;D9[1]=0.000;D9[2]=5.500;D9[3]=13.000;D9[4]=12.300;D9[5]=5.200;D9[6]=9.000;D9[7]=10.400;D9[8]=5.200;D9[9]=0.000;D9[10]=11.300;D9[11]=4.900;D9[12]=5.700;D9[13]=11.600;D9[14]=0.000;D9[15]=8.000;D9[16]=10.500;D9[17]=10.500;D9[18]=9.200;D9[19]=8.600;D9[20]=0.000;D9[21]=5.900;D9[22]=5.400;D9[23]=0.000;D9[24]=6.200;D9[25]=0.000;
#10 aa-polar-radzicka.aaindex
D10[0]=-0.060;D10[1]=0.000;D10[2]=1.360;D10[3]=-0.800;D10[4]=-0.770;D10[5]=1.270;D10[6]=-0.410;D10[7]=0.490;D10[8]=1.310;D10[9]=0.000;D10[10]=-1.180;D10[11]=1.210;D10[12]=1.270;D10[13]=-0.480;D10[14]=0.000;D10[15]=1.100;D10[16]=-0.730;D10[17]=-0.840;D10[18]=-0.500;D10[19]=-0.270;D10[20]=0.000;D10[21]=1.090;D10[22]=0.880;D10[23]=0.000;D10[24]=0.330;D10[25]=0.000;
#11 aa-polar-zimmerman.aaindex
D11[0]=0.000;D11[1]=0.000;D11[2]=1.480;D11[3]=49.700;D11[4]=49.900;D11[5]=0.350;D11[6]=0.000;D11[7]=51.600;D11[8]=0.130;D11[9]=0.000;D11[10]=49.500;D11[11]=0.130;D11[12]=1.430;D11[13]=3.380;D11[14]=0.000;D11[15]=1.580;D11[16]=3.530;D11[17]=52.000;D11[18]=1.670;D11[19]=1.660;D11[20]=0.000;D11[21]=0.130;D11[22]=2.100;D11[23]=0.000;D11[24]=1.610;D11[25]=0.000;
#12 aa-volume.aaindex
D12[0]=90.000;D12[1]=0.000;D12[2]=103.300;D12[3]=117.300;D12[4]=142.200;D12[5]=191.900;D12[6]=64.900;D12[7]=160.000;D12[8]=163.900;D12[9]=0.000;D12[10]=167.300;D12[11]=164.000;D12[12]=167.000;D12[13]=124.700;D12[14]=0.000;D12[15]=122.900;D12[16]=149.400;D12[17]=194.000;D12[18]=95.400;D12[19]=121.500;D12[20]=0.000;D12[21]=139.000;D12[22]=228.200;D12[23]=0.000;D12[24]=197.000;D12[25]=0.000;

# %%
# Map Amino acid abbreviations with indices of D[i, :]

aa2ind_map = {}
aa2ind_map['A'] = 0
aa2ind_map['R'] = 17
aa2ind_map['D'] = 3
aa2ind_map['N'] = 13
aa2ind_map['C'] = 2
aa2ind_map['E'] = 4
aa2ind_map['Q'] = 16
aa2ind_map['G'] = 6
aa2ind_map['H'] = 7
aa2ind_map['I'] = 8
aa2ind_map['L'] = 11
aa2ind_map['K'] = 10
aa2ind_map['M'] = 12
aa2ind_map['F'] = 5
aa2ind_map['P'] = 15
aa2ind_map['S'] = 18
aa2ind_map['T'] = 19
aa2ind_map['W'] = 22
aa2ind_map['Y'] = 24
aa2ind_map['V'] = 21

# %%
# Dictionary to store 15 dimensional vector values for each amino acid

aa_dict = {}
for i, row in z_scores_df.iterrows():
    aa_dict[row['aa_short']] = [row['z1'], row['z2'], row['z3'], ] # Store z values
    aa_dict[row['aa_short']].extend(D[:, aa2ind_map[row['aa_short']]]) # Store rest of the 12 hard-coded values
aa_dict['-'] = list(np.mean(np.asarray(list(aa_dict.values())), axis=0))

# %%
# Create index to value map and value to index map from a list using list index
def get_dict_from_list(mylist):
    assert len(mylist) > 0
    idx_to_value_dict = {}
    value_to_idx_dict = {}
    for i in range(len(mylist)):
        idx_to_value_dict[i] = mylist[i]
        value_to_idx_dict[mylist[i]] = int(i)
    return idx_to_value_dict, value_to_idx_dict

# Get index-value maps for substrates
sub_vocab_set = set(df_original['sub'].tolist())
sub_vocab_list = list(sub_vocab_set)
sub_idx_to_value_dict, sub_value_to_idx_dict = get_dict_from_list(sub_vocab_list)

# %%
sub_idx_to_value_dict
# Out:
# {0: 'asn',
#  1: 'orn',
#  2: 'dht',
#  3: 'pro',
#  4: 'hpg',
#  5: 'dhpg',
#  6: 'arg',
#  7: 'asp',
#  8: 'ile',
#  9: 'lys',
#  10: 'leu',
#  11: 'cys',
#  12: 'val',
#  13: 'ser',
#  14: 'ORN',
#  15: 'ala',
#  16: 'tyr',
#  17: 'hyv-d',
#  18: 'gln',
#  19: 'beta-ala',
#  20: 'pip',
#  21: 'aad',
#  22: 'dab',
#  23: 'trp',
#  24: 'dhb',
#  25: 'glu',
#  26: 'bht',
#  27: 'gly',
#  28: 'horn',
#  29: 'thr',
#  30: 'phe'}

# %%
# Remove the entries with only one substrate occurence
df_cnt_filtered = df_original.groupby('sub').filter(lambda x: len(x) > 1)
print("Reduced data size from ",len(df_original)," to ", len(df_cnt_filtered), " due to count filtering")
# Out:
# Reduced data size from  1534  to  1533  due to count filtering

# %%
# Re-Create substrate index-value maps after removing the substrates with count 1

sub_vocab_set = set(df_cnt_filtered['sub'].tolist())
sub_vocab_list = list(sub_vocab_set)
sub_idx_to_value_dict, sub_value_to_idx_dict = get_dict_from_list(sub_vocab_list)

# %%
# Given a signature of amino acids(34 aa long), construct the 34x15=510 dimentional representation
def get_encoding(signature):
    ret = []
    for i in signature:
        ret.extend(aa_dict[i])
    return np.asarray(ret)

# %%
# Format the data
def format_data_from_df(df_in):
    sig_len = 34
    raw_data = []
    data_np = []
    label_np = []
    j=0
    for i, row in df_cnt_filtered.iterrows():
        assert len(row['sig']) == sig_len
        raw_data.append(row['sig'])
        data_np.append(get_encoding(row['sig']))
        label_np.append(sub_value_to_idx_dict[row['sub']])
        j+=1
    return np.asarray(data_np), np.asarray(label_np).astype('int'), np.array(raw_data)

data_np, label_np, raw_data = format_data_from_df(df_original)

#data_np = np.asarray(data_np)
#label_np = np.asarray(label_np).astype('int')
#raw_data = np.array(raw_data)

# %%
def get_hamming_distance(str1, str2):
    return sum(i != j for i, j in zip(str1, str2))

# For all points in test_data, choose the minimum hamming distance from all of train data, and return the distance list
def get_hamming_distance_bucket_info(test_data, train_data):
    dist_list = []
    for test_data_pt in test_data:
        dist_list.append(min([get_hamming_distance(test_data_pt, train_data_pt) for train_data_pt in train_data]))
    return np.array(dist_list)

def round_dec(num, dec=2):
    return float(round(num* 10.**dec))/(10**dec)

# %%
# Build classifier dictionary using sklearn multiclass classifiers

clf_dict={}
clf_dict['lr'] = LogisticRegression(random_state=0, max_iter=400, multi_class='multinomial', solver='newton-cg')
clf_dict['svm'] = make_pipeline(StandardScaler(), LinearSVC(random_state=0, multi_class='crammer_singer', tol=1e-9, max_iter=2000))
clf_dict['knn'] = KNeighborsClassifier(weights='distance')
clf_dict['mlp_sklearn'] = MLPClassifier(random_state=1, max_iter=400, early_stopping=False, )
clf_dict['rand_for'] = RandomForestClassifier(max_depth=4, criterion='entropy')
clf_dict['dec_tree'] = DecisionTreeClassifier(random_state=0, criterion='entropy')
clf_dict['ber_nb'] = BernoulliNB()
clf_dict['xtra_tree'] = ExtraTreesClassifier(n_estimators=100, random_state=0, criterion='gini')
clf_dict['gau_nb'] = GaussianNB()
clf_dict['label_prop'] = LabelPropagation(kernel='knn')
clf_dict['label_spread'] = LabelSpreading(kernel='knn')
clf_dict['lda'] = LinearDiscriminantAnalysis()
clf_dict['ridge_cv'] = RidgeClassifierCV()
clf_dict['n_cent'] = NearestCentroid()
clf_dict['ridge'] = RidgeClassifier()

# %%
def print_stats(metric_list, metric_list_bucket, n_bucket):
    print(f"\n\nOverall Stats:")

    for item in metric_list:
        print(f"Test percentage: {item['pct']:.2f} Average Accuracy: {item['acc']:.3f} Average Recall: {item['rec']:.3f} Average Precision: {item['pre']:.3f} Average F1 Score: {item['f1']:.3f}")

    for bucket in range(n_bucket):
        print(f"\n\nBucket {bucket+1} Stats:")
        for item in metric_list_bucket:
            print(f"Test percentage: {item['pct']:.2f} Average Accuracy: {item['acc'][bucket]:.3f} Average Recall: {item['rec'][bucket]:.3f} Average Precision: {item['pre'][bucket]:.3f} Average F1 Score: {item['f1'][bucket]:.3f}")

def save_stats(metric_list, metric_list_bucket, n_bucket, pct_list, csv_name='stats'):
    overall_dict = {}
    for item in metric_list:
        overall_dict[item['pct']] = item['acc']
    
    with open(csv_name + '.csv', 'w', newline='') as csvfile:
        fieldnames = ['pct', 'overall_acc'] + ['Bucket '+str(item) for item in range(n_bucket)]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for item in metric_list_bucket:
            temp_dict = {'pct': item['pct'], 'overall_acc': round_dec(overall_dict[item['pct']])}
            for bucket in range(n_bucket):
                temp_dict['Bucket ' + str(bucket)] = round_dec(item['acc'][bucket])
            writer.writerow(temp_dict)

# n_iter signifies number of iterations
# test_percentage_list is the list of percentages of test data with respect to total data
# Code will iterate for each percentage for n_iter iterations
def train_and_validate(clf_type, n_iter=10, test_percentage_list = [5, 10, 25, 40, 50], print_stat=True, save_stat=True):
    print(f'\nUsing {clf_type} classifier')
    n=len(label_np)
    avg = 'micro'
    # metric_list contains overall accuracy, precision, recall and f1 score for all data
    # metric_list_bucket contains hammning distance bucket-wise accuracy, precision, recall and f1 score
    metric_list = []
    metric_list_bucket = []
    n_bucket = 6
    eps = 1e-8

    for test_percentage in test_percentage_list:
        assert test_percentage>0 and test_percentage<100
        acc_sum = 0
        pre_sum = 0
        rec_sum = 0
        f1_sum = 0
        print(f'Test data percentage wrt total data: {test_percentage}')
        n_iter_ar = np.zeros(n_bucket)
        acc_sum_ar = np.zeros(n_bucket)
        pre_sum_ar = np.zeros(n_bucket)
        rec_sum_ar = np.zeros(n_bucket)
        f1_sum_ar = np.zeros(n_bucket)
        dist_buckets_all = []

        for iter in range(n_iter):
            # Create filter for random split
            test_elig = np.random.random(size=(n)) <= (test_percentage/100)
            test_data = data_np[test_elig]
            test_label = label_np[test_elig]
            train_data = data_np[(test_elig-1).astype('bool')]
            train_label = label_np[(test_elig-1).astype('bool')]

            raw_train_data = raw_data[(test_elig-1).astype('bool')]
            raw_test_data = raw_data[test_elig]
            dist_buckets = get_hamming_distance_bucket_info(raw_test_data, raw_train_data)
            dist_buckets_all.extend(list(dist_buckets))
            #print(dist_buckets)

            clf = clf_dict[clf_type]
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                clf.fit(train_data, train_label)
            test_predicted = clf.predict(test_data)

            accuracy = acc(test_label, test_predicted)
            precision = pre(test_label, test_predicted, average=avg)
            recall = rec(test_label, test_predicted, average=avg)
            f1_score = f1(test_label, test_predicted, average=avg)
            acc_sum += accuracy
            pre_sum += precision
            rec_sum += recall
            f1_sum += f1_score
            print(f'Accuracy: {accuracy:.3f} Recall: {recall:.3f} Precision: {precision:.3f} F1 Score: {f1_score:.3f}')

            for bucket in range(n_bucket):
                b_filter = dist_buckets == bucket
                filtered_test_label = test_label[b_filter]
                filtered_test_predicted = test_predicted[b_filter]
                if len(filtered_test_label):
                    accuracy = acc(filtered_test_label, filtered_test_predicted)
                    precision = pre(filtered_test_label, filtered_test_predicted, average=avg)
                    recall = rec(filtered_test_label, filtered_test_predicted, average=avg)
                    f1_score = f1(filtered_test_label, filtered_test_predicted, average=avg)
                    acc_sum_ar[bucket] += accuracy
                    pre_sum_ar[bucket] += precision
                    rec_sum_ar[bucket] += recall
                    f1_sum_ar[bucket] += f1_score
                    n_iter_ar[bucket] += 1


        metric_list.append({'pct':test_percentage, 'acc':acc_sum/n_iter, 'pre':pre_sum/n_iter, 'rec':rec_sum/n_iter, 'f1':f1_sum/n_iter})
        metric_list_bucket.append({'pct':test_percentage, 'acc':acc_sum_ar/(n_iter+eps), 'pre':pre_sum_ar/(n_iter+eps), 'rec':rec_sum_ar/(n_iter+eps), 'f1':f1_sum_ar/(n_iter+eps)})
        freq_stat = {value: round_dec(len(list(freq))*100./len(dist_buckets_all), 2) for value, freq in groupby(sorted(dist_buckets_all))}
        print(f"Frequency of hamming distance: ", freq_stat)


    if print_stat:
        print_stats(metric_list, metric_list_bucket, n_bucket)
    if save_stat:
        save_stats(metric_list, metric_list_bucket, n_bucket, test_percentage_list, csv_name='../results/Adomain_Subs_stats_'+clf_type+'_iter_'+str(n_iter)+'_pct_'+'_'.join(map(str, test_percentage_list)))
    return {'overall':metric_list, 'bucket':metric_list_bucket}

# %%
def save_consolidated_stats(metric_struct, metric_bucket_struct):
    algos = list(metric_struct.keys())
    if algos == []:
        return
    pct_list = [item['pct'] for item in metric_struct[algos[0]]]
    n_bucket = len(metric_bucket_struct[algos[0]][0]['acc'])
    overall_struct = {}
    bucket_struct = {}
    for algo in algos:
        temp = {}
        for item in metric_struct[algo]:
            temp[item['pct']] = round_dec(item['acc'])
        overall_struct[algo] = temp
        temp = {}
        for item in metric_bucket_struct[algo]:
            temp[item['pct']] = [round_dec(it) for it in item['acc']]
        bucket_struct[algo] = temp
    for pct in pct_list:
        with open('../results/Adomain_Subs_consolidated_stats_algo_'+'_'.join(map(str, algos))+'pct_'+str(pct)+'_bucket_'+str(n_bucket)+ '.csv', 'w', newline='') as csvfile:
            Bucket_fields = ['Bucket '+str(item) for item in range(n_bucket)]
            fieldnames = ['Algo', 'Overall'] + Bucket_fields
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()
            for algo in algos:
                temp = {'Algo': algo, 'Overall':overall_struct[algo][pct]}
                temp.update(dict(zip(Bucket_fields, bucket_struct[algo][pct])))
                writer.writerow(temp)

# %%
algo_overall_metric = {}
algo_bucket_metric = {}
for clf in list(clf_dict.keys()):
    ret = train_and_validate(clf)
    algo_overall_metric[clf] = ret['overall']
    algo_bucket_metric[clf] = ret['bucket']
save_consolidated_stats(algo_overall_metric, algo_bucket_metric)
# Out:
# Using lr classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.784 Recall: 0.784 Precision: 0.784 F1 Score: 0.784
# Accuracy: 0.841 Recall: 0.841 Precision: 0.841 F1 Score: 0.841
# Accuracy: 0.885 Recall: 0.885 Precision: 0.885 F1 Score: 0.885
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.894 Recall: 0.894 Precision: 0.894 F1 Score: 0.894
# Accuracy: 0.900 Recall: 0.900 Precision: 0.900 F1 Score: 0.900
# Accuracy: 0.869 Recall: 0.869 Precision: 0.869 F1 Score: 0.869
# Accuracy: 0.850 Recall: 0.850 Precision: 0.850 F1 Score: 0.850
# Accuracy: 0.886 Recall: 0.886 Precision: 0.886 F1 Score: 0.886
# Frequency of hamming distance:  {0: 66.96, 1: 8.32, 2: 3.23, 3: 4.22, 4: 0.99, 5: 2.86, 6: 1.61, 7: 1.37, 8: 1.49, 9: 1.49, 10: 1.37, 11: 1.24, 12: 0.75, 13: 1.12, 14: 0.5, 15: 1.24, 16: 0.75, 18: 0.25, 20: 0.12, 23: 0.12}
# Test data percentage wrt total data: 10
# Accuracy: 0.854 Recall: 0.854 Precision: 0.854 F1 Score: 0.854
# Accuracy: 0.827 Recall: 0.827 Precision: 0.827 F1 Score: 0.827
# Accuracy: 0.845 Recall: 0.845 Precision: 0.845 F1 Score: 0.845
# Accuracy: 0.785 Recall: 0.785 Precision: 0.785 F1 Score: 0.785
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.860 Recall: 0.860 Precision: 0.860 F1 Score: 0.860
# Accuracy: 0.892 Recall: 0.892 Precision: 0.892 F1 Score: 0.892
# Accuracy: 0.856 Recall: 0.856 Precision: 0.856 F1 Score: 0.856
# Accuracy: 0.801 Recall: 0.801 Precision: 0.801 F1 Score: 0.801
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Frequency of hamming distance:  {0: 66.15, 1: 7.47, 2: 3.51, 3: 4.61, 4: 2.01, 5: 2.66, 6: 0.91, 7: 1.36, 8: 1.04, 9: 0.97, 10: 1.1, 11: 1.23, 12: 1.3, 13: 1.23, 14: 0.84, 15: 0.84, 16: 0.97, 17: 0.19, 18: 0.45, 20: 0.06, 21: 0.19, 22: 0.19, 23: 0.39, 24: 0.26}
# Test data percentage wrt total data: 25
# Accuracy: 0.836 Recall: 0.836 Precision: 0.836 F1 Score: 0.836
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.774 Recall: 0.774 Precision: 0.774 F1 Score: 0.774
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.857 Recall: 0.857 Precision: 0.857 F1 Score: 0.857
# Accuracy: 0.830 Recall: 0.830 Precision: 0.830 F1 Score: 0.830
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.830 Recall: 0.830 Precision: 0.830 F1 Score: 0.830
# Accuracy: 0.825 Recall: 0.825 Precision: 0.825 F1 Score: 0.825
# Frequency of hamming distance:  {0: 62.62, 1: 7.43, 2: 5.14, 3: 3.89, 4: 1.83, 5: 2.87, 6: 1.23, 7: 1.67, 8: 1.25, 9: 1.36, 10: 1.1, 11: 1.85, 12: 1.8, 13: 1.15, 14: 1.23, 15: 1.04, 16: 0.78, 17: 0.21, 18: 0.26, 19: 0.1, 20: 0.26, 21: 0.16, 22: 0.31, 23: 0.39, 24: 0.08}
# Test data percentage wrt total data: 40
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.805 Recall: 0.805 Precision: 0.805 F1 Score: 0.805
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.802 Recall: 0.802 Precision: 0.802 F1 Score: 0.802
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.813 Recall: 0.813 Precision: 0.813 F1 Score: 0.813
# Accuracy: 0.804 Recall: 0.804 Precision: 0.804 F1 Score: 0.804
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.822 Recall: 0.822 Precision: 0.822 F1 Score: 0.822
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Frequency of hamming distance:  {0: 60.02, 1: 7.16, 2: 5.36, 3: 4.09, 4: 2.14, 5: 2.89, 6: 1.64, 7: 1.79, 8: 1.88, 9: 1.59, 10: 1.41, 11: 1.72, 12: 1.4, 13: 1.48, 14: 1.17, 15: 1.06, 16: 0.93, 17: 0.34, 18: 0.36, 19: 0.21, 20: 0.19, 21: 0.34, 22: 0.32, 23: 0.32, 24: 0.18}
# Test data percentage wrt total data: 50
# Accuracy: 0.791 Recall: 0.791 Precision: 0.791 F1 Score: 0.791
# Accuracy: 0.817 Recall: 0.817 Precision: 0.817 F1 Score: 0.817
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.824 Recall: 0.824 Precision: 0.824 F1 Score: 0.824
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.827 Recall: 0.827 Precision: 0.827 F1 Score: 0.827
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.815 Recall: 0.815 Precision: 0.815 F1 Score: 0.815
# Frequency of hamming distance:  {0: 58.95, 1: 7.06, 2: 5.24, 3: 4.64, 4: 2.13, 5: 2.73, 6: 1.7, 7: 1.75, 8: 1.48, 9: 1.74, 10: 1.57, 11: 1.42, 12: 2.06, 13: 1.42, 14: 1.27, 15: 1.37, 16: 0.97, 17: 0.47, 18: 0.41, 19: 0.22, 20: 0.26, 21: 0.34, 22: 0.35, 23: 0.25, 24: 0.18, 25: 0.01}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.856 Average Recall: 0.856 Average Precision: 0.856 Average F1 Score: 0.856
# Test percentage: 10.00 Average Accuracy: 0.839 Average Recall: 0.839 Average Precision: 0.839 Average F1 Score: 0.839
# Test percentage: 25.00 Average Accuracy: 0.824 Average Recall: 0.824 Average Precision: 0.824 Average F1 Score: 0.824
# Test percentage: 40.00 Average Accuracy: 0.816 Average Recall: 0.816 Average Precision: 0.816 Average F1 Score: 0.816
# Test percentage: 50.00 Average Accuracy: 0.819 Average Recall: 0.819 Average Precision: 0.819 Average F1 Score: 0.819
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.989 Average Recall: 0.989 Average Precision: 0.989 Average F1 Score: 0.989
# Test percentage: 10.00 Average Accuracy: 0.987 Average Recall: 0.987 Average Precision: 0.987 Average F1 Score: 0.987
# Test percentage: 25.00 Average Accuracy: 0.987 Average Recall: 0.987 Average Precision: 0.987 Average F1 Score: 0.987
# Test percentage: 40.00 Average Accuracy: 0.987 Average Recall: 0.987 Average Precision: 0.987 Average F1 Score: 0.987
# Test percentage: 50.00 Average Accuracy: 0.988 Average Recall: 0.988 Average Precision: 0.988 Average F1 Score: 0.988
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.825 Average Recall: 0.825 Average Precision: 0.825 Average F1 Score: 0.825
# Test percentage: 10.00 Average Accuracy: 0.835 Average Recall: 0.835 Average Precision: 0.835 Average F1 Score: 0.835
# Test percentage: 25.00 Average Accuracy: 0.869 Average Recall: 0.869 Average Precision: 0.869 Average F1 Score: 0.869
# Test percentage: 40.00 Average Accuracy: 0.881 Average Recall: 0.881 Average Precision: 0.881 Average F1 Score: 0.881
# Test percentage: 50.00 Average Accuracy: 0.885 Average Recall: 0.885 Average Precision: 0.885 Average F1 Score: 0.885
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.832 Average Recall: 0.832 Average Precision: 0.832 Average F1 Score: 0.832
# Test percentage: 10.00 Average Accuracy: 0.813 Average Recall: 0.813 Average Precision: 0.813 Average F1 Score: 0.813
# Test percentage: 25.00 Average Accuracy: 0.754 Average Recall: 0.754 Average Precision: 0.754 Average F1 Score: 0.754
# Test percentage: 40.00 Average Accuracy: 0.821 Average Recall: 0.821 Average Precision: 0.821 Average F1 Score: 0.821
# Test percentage: 50.00 Average Accuracy: 0.847 Average Recall: 0.847 Average Precision: 0.847 Average F1 Score: 0.847
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.794 Average Recall: 0.794 Average Precision: 0.794 Average F1 Score: 0.794
# Test percentage: 10.00 Average Accuracy: 0.691 Average Recall: 0.691 Average Precision: 0.691 Average F1 Score: 0.691
# Test percentage: 25.00 Average Accuracy: 0.733 Average Recall: 0.733 Average Precision: 0.733 Average F1 Score: 0.733
# Test percentage: 40.00 Average Accuracy: 0.810 Average Recall: 0.810 Average Precision: 0.810 Average F1 Score: 0.810
# Test percentage: 50.00 Average Accuracy: 0.840 Average Recall: 0.840 Average Precision: 0.840 Average F1 Score: 0.840
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.317 Average Recall: 0.317 Average Precision: 0.317 Average F1 Score: 0.317
# Test percentage: 10.00 Average Accuracy: 0.654 Average Recall: 0.654 Average Precision: 0.654 Average F1 Score: 0.654
# Test percentage: 25.00 Average Accuracy: 0.615 Average Recall: 0.615 Average Precision: 0.615 Average F1 Score: 0.615
# Test percentage: 40.00 Average Accuracy: 0.660 Average Recall: 0.660 Average Precision: 0.660 Average F1 Score: 0.660
# Test percentage: 50.00 Average Accuracy: 0.632 Average Recall: 0.632 Average Precision: 0.632 Average F1 Score: 0.632
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.442 Average Recall: 0.442 Average Precision: 0.442 Average F1 Score: 0.442
# Test percentage: 10.00 Average Accuracy: 0.540 Average Recall: 0.540 Average Precision: 0.540 Average F1 Score: 0.540
# Test percentage: 25.00 Average Accuracy: 0.503 Average Recall: 0.503 Average Precision: 0.503 Average F1 Score: 0.503
# Test percentage: 40.00 Average Accuracy: 0.588 Average Recall: 0.588 Average Precision: 0.588 Average F1 Score: 0.588
# Test percentage: 50.00 Average Accuracy: 0.651 Average Recall: 0.651 Average Precision: 0.651 Average F1 Score: 0.651
#
# Using svm classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.868 Recall: 0.868 Precision: 0.868 F1 Score: 0.868
# Accuracy: 0.884 Recall: 0.884 Precision: 0.884 F1 Score: 0.884
# Accuracy: 0.863 Recall: 0.863 Precision: 0.863 F1 Score: 0.863
# Accuracy: 0.928 Recall: 0.928 Precision: 0.928 F1 Score: 0.928
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.882 Recall: 0.882 Precision: 0.882 F1 Score: 0.882
# Accuracy: 0.871 Recall: 0.871 Precision: 0.871 F1 Score: 0.871
# Accuracy: 0.805 Recall: 0.805 Precision: 0.805 F1 Score: 0.805
# Frequency of hamming distance:  {0: 64.98, 1: 7.78, 2: 4.41, 3: 3.89, 4: 1.3, 5: 2.59, 6: 0.65, 7: 1.82, 8: 2.08, 9: 1.82, 10: 0.91, 11: 0.91, 12: 1.43, 13: 1.17, 14: 1.17, 15: 0.78, 16: 0.26, 17: 0.52, 18: 0.39, 21: 0.39, 22: 0.52, 23: 0.13, 24: 0.13}
# Test data percentage wrt total data: 10
# Accuracy: 0.861 Recall: 0.861 Precision: 0.861 F1 Score: 0.861
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.832 Recall: 0.832 Precision: 0.832 F1 Score: 0.832
# Accuracy: 0.853 Recall: 0.853 Precision: 0.853 F1 Score: 0.853
# Accuracy: 0.861 Recall: 0.861 Precision: 0.861 F1 Score: 0.861
# Accuracy: 0.857 Recall: 0.857 Precision: 0.857 F1 Score: 0.857
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Accuracy: 0.812 Recall: 0.812 Precision: 0.812 F1 Score: 0.812
# Accuracy: 0.835 Recall: 0.835 Precision: 0.835 F1 Score: 0.835
# Frequency of hamming distance:  {0: 64.8, 1: 7.54, 2: 3.9, 3: 4.15, 4: 2.33, 5: 3.14, 6: 1.51, 7: 1.38, 8: 0.88, 9: 1.7, 10: 0.88, 11: 1.38, 12: 1.57, 13: 0.88, 14: 0.38, 15: 1.19, 16: 0.82, 17: 0.06, 18: 0.31, 20: 0.19, 21: 0.25, 22: 0.38, 23: 0.25, 24: 0.13}
# Test data percentage wrt total data: 25
# Accuracy: 0.879 Recall: 0.879 Precision: 0.879 F1 Score: 0.879
# Accuracy: 0.808 Recall: 0.808 Precision: 0.808 F1 Score: 0.808
# Accuracy: 0.878 Recall: 0.878 Precision: 0.878 F1 Score: 0.878
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.860 Recall: 0.860 Precision: 0.860 F1 Score: 0.860
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.892 Recall: 0.892 Precision: 0.892 F1 Score: 0.892
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Accuracy: 0.835 Recall: 0.835 Precision: 0.835 F1 Score: 0.835
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Frequency of hamming distance:  {0: 63.19, 1: 7.1, 2: 4.54, 3: 4.3, 4: 2.11, 5: 2.59, 6: 1.27, 7: 1.79, 8: 1.48, 9: 1.35, 10: 1.0, 11: 1.64, 12: 1.4, 13: 1.27, 14: 1.16, 15: 0.87, 16: 1.13, 17: 0.18, 18: 0.47, 19: 0.18, 20: 0.18, 21: 0.24, 22: 0.18, 23: 0.32, 24: 0.05}
# Test data percentage wrt total data: 40
# Accuracy: 0.840 Recall: 0.840 Precision: 0.840 F1 Score: 0.840
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Accuracy: 0.835 Recall: 0.835 Precision: 0.835 F1 Score: 0.835
# Accuracy: 0.855 Recall: 0.855 Precision: 0.855 F1 Score: 0.855
# Accuracy: 0.824 Recall: 0.824 Precision: 0.824 F1 Score: 0.824
# Accuracy: 0.834 Recall: 0.834 Precision: 0.834 F1 Score: 0.834
# Accuracy: 0.845 Recall: 0.845 Precision: 0.845 F1 Score: 0.845
# Accuracy: 0.836 Recall: 0.836 Precision: 0.836 F1 Score: 0.836
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Frequency of hamming distance:  {0: 60.55, 1: 7.15, 2: 5.16, 3: 4.16, 4: 2.04, 5: 2.97, 6: 1.27, 7: 1.93, 8: 1.42, 9: 1.36, 10: 1.63, 11: 1.71, 12: 1.63, 13: 1.31, 14: 1.21, 15: 1.19, 16: 1.0, 17: 0.44, 18: 0.41, 19: 0.24, 20: 0.23, 21: 0.16, 22: 0.28, 23: 0.29, 24: 0.23, 25: 0.02}
# Test data percentage wrt total data: 50
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.813 Recall: 0.813 Precision: 0.813 F1 Score: 0.813
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.841 Recall: 0.841 Precision: 0.841 F1 Score: 0.841
# Frequency of hamming distance:  {0: 59.17, 1: 6.64, 2: 5.59, 3: 4.18, 4: 2.49, 5: 2.89, 6: 1.82, 7: 1.97, 8: 1.38, 9: 1.41, 10: 1.83, 11: 1.65, 12: 1.58, 13: 1.18, 14: 1.39, 15: 1.14, 16: 1.22, 17: 0.64, 18: 0.43, 19: 0.25, 20: 0.17, 21: 0.26, 22: 0.26, 23: 0.27, 24: 0.13, 25: 0.05}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.859 Average Recall: 0.859 Average Precision: 0.859 Average F1 Score: 0.859
# Test percentage: 10.00 Average Accuracy: 0.843 Average Recall: 0.843 Average Precision: 0.843 Average F1 Score: 0.843
# Test percentage: 25.00 Average Accuracy: 0.853 Average Recall: 0.853 Average Precision: 0.853 Average F1 Score: 0.853
# Test percentage: 40.00 Average Accuracy: 0.840 Average Recall: 0.840 Average Precision: 0.840 Average F1 Score: 0.840
# Test percentage: 50.00 Average Accuracy: 0.828 Average Recall: 0.828 Average Precision: 0.828 Average F1 Score: 0.828
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.990 Average Recall: 0.990 Average Precision: 0.990 Average F1 Score: 0.990
# Test percentage: 10.00 Average Accuracy: 0.982 Average Recall: 0.982 Average Precision: 0.982 Average F1 Score: 0.982
# Test percentage: 25.00 Average Accuracy: 0.992 Average Recall: 0.992 Average Precision: 0.992 Average F1 Score: 0.992
# Test percentage: 40.00 Average Accuracy: 0.990 Average Recall: 0.990 Average Precision: 0.990 Average F1 Score: 0.990
# Test percentage: 50.00 Average Accuracy: 0.989 Average Recall: 0.989 Average Precision: 0.989 Average F1 Score: 0.989
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.937 Average Recall: 0.937 Average Precision: 0.937 Average F1 Score: 0.937
# Test percentage: 10.00 Average Accuracy: 0.852 Average Recall: 0.852 Average Precision: 0.852 Average F1 Score: 0.852
# Test percentage: 25.00 Average Accuracy: 0.873 Average Recall: 0.873 Average Precision: 0.873 Average F1 Score: 0.873
# Test percentage: 40.00 Average Accuracy: 0.894 Average Recall: 0.894 Average Precision: 0.894 Average F1 Score: 0.894
# Test percentage: 50.00 Average Accuracy: 0.879 Average Recall: 0.879 Average Precision: 0.879 Average F1 Score: 0.879
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.950 Average Recall: 0.950 Average Precision: 0.950 Average F1 Score: 0.950
# Test percentage: 10.00 Average Accuracy: 0.966 Average Recall: 0.966 Average Precision: 0.966 Average F1 Score: 0.966
# Test percentage: 25.00 Average Accuracy: 0.871 Average Recall: 0.871 Average Precision: 0.871 Average F1 Score: 0.871
# Test percentage: 40.00 Average Accuracy: 0.880 Average Recall: 0.880 Average Precision: 0.880 Average F1 Score: 0.880
# Test percentage: 50.00 Average Accuracy: 0.881 Average Recall: 0.881 Average Precision: 0.881 Average F1 Score: 0.881
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.705 Average Recall: 0.705 Average Precision: 0.705 Average F1 Score: 0.705
# Test percentage: 10.00 Average Accuracy: 0.875 Average Recall: 0.875 Average Precision: 0.875 Average F1 Score: 0.875
# Test percentage: 25.00 Average Accuracy: 0.807 Average Recall: 0.807 Average Precision: 0.807 Average F1 Score: 0.807
# Test percentage: 40.00 Average Accuracy: 0.879 Average Recall: 0.879 Average Precision: 0.879 Average F1 Score: 0.879
# Test percentage: 50.00 Average Accuracy: 0.845 Average Recall: 0.845 Average Precision: 0.845 Average F1 Score: 0.845
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.600 Average Recall: 0.600 Average Precision: 0.600 Average F1 Score: 0.600
# Test percentage: 10.00 Average Accuracy: 0.485 Average Recall: 0.485 Average Precision: 0.485 Average F1 Score: 0.485
# Test percentage: 25.00 Average Accuracy: 0.715 Average Recall: 0.715 Average Precision: 0.715 Average F1 Score: 0.715
# Test percentage: 40.00 Average Accuracy: 0.687 Average Recall: 0.687 Average Precision: 0.687 Average F1 Score: 0.687
# Test percentage: 50.00 Average Accuracy: 0.756 Average Recall: 0.756 Average Precision: 0.756 Average F1 Score: 0.756
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.483 Average Recall: 0.483 Average Precision: 0.483 Average F1 Score: 0.483
# Test percentage: 10.00 Average Accuracy: 0.368 Average Recall: 0.368 Average Precision: 0.368 Average F1 Score: 0.368
# Test percentage: 25.00 Average Accuracy: 0.631 Average Recall: 0.631 Average Precision: 0.631 Average F1 Score: 0.631
# Test percentage: 40.00 Average Accuracy: 0.630 Average Recall: 0.630 Average Precision: 0.630 Average F1 Score: 0.630
# Test percentage: 50.00 Average Accuracy: 0.626 Average Recall: 0.626 Average Precision: 0.626 Average F1 Score: 0.626
#
# Using knn classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.862 Recall: 0.862 Precision: 0.862 F1 Score: 0.862
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Accuracy: 0.932 Recall: 0.932 Precision: 0.932 F1 Score: 0.932
# Accuracy: 0.789 Recall: 0.789 Precision: 0.789 F1 Score: 0.789
# Accuracy: 0.877 Recall: 0.877 Precision: 0.877 F1 Score: 0.877
# Accuracy: 0.865 Recall: 0.865 Precision: 0.865 F1 Score: 0.865
# Accuracy: 0.844 Recall: 0.844 Precision: 0.844 F1 Score: 0.844
# Accuracy: 0.812 Recall: 0.812 Precision: 0.812 F1 Score: 0.812
# Accuracy: 0.899 Recall: 0.899 Precision: 0.899 F1 Score: 0.899
# Accuracy: 0.785 Recall: 0.785 Precision: 0.785 F1 Score: 0.785
# Frequency of hamming distance:  {0: 65.57, 1: 6.58, 2: 4.39, 3: 4.39, 4: 1.92, 5: 3.57, 6: 0.96, 7: 1.1, 8: 1.65, 9: 0.96, 10: 0.82, 11: 0.69, 12: 1.92, 13: 1.1, 14: 0.55, 15: 1.1, 16: 0.69, 17: 0.14, 18: 0.41, 20: 0.14, 22: 0.27, 23: 0.82, 24: 0.27}
# Test data percentage wrt total data: 10
# Accuracy: 0.856 Recall: 0.856 Precision: 0.856 F1 Score: 0.856
# Accuracy: 0.870 Recall: 0.870 Precision: 0.870 F1 Score: 0.870
# Accuracy: 0.921 Recall: 0.921 Precision: 0.921 F1 Score: 0.921
# Accuracy: 0.860 Recall: 0.860 Precision: 0.860 F1 Score: 0.860
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Accuracy: 0.872 Recall: 0.872 Precision: 0.872 F1 Score: 0.872
# Accuracy: 0.868 Recall: 0.868 Precision: 0.868 F1 Score: 0.868
# Accuracy: 0.805 Recall: 0.805 Precision: 0.805 F1 Score: 0.805
# Accuracy: 0.912 Recall: 0.912 Precision: 0.912 F1 Score: 0.912
# Accuracy: 0.887 Recall: 0.887 Precision: 0.887 F1 Score: 0.887
# Frequency of hamming distance:  {0: 66.87, 1: 6.53, 2: 4.67, 3: 3.73, 4: 1.6, 5: 2.8, 6: 1.07, 7: 1.33, 8: 1.07, 9: 1.53, 10: 0.53, 11: 1.67, 12: 1.4, 13: 1.27, 14: 1.33, 15: 0.93, 16: 0.6, 17: 0.2, 18: 0.13, 20: 0.13, 21: 0.07, 22: 0.13, 23: 0.33, 24: 0.07}
# Test data percentage wrt total data: 25
# Accuracy: 0.845 Recall: 0.845 Precision: 0.845 F1 Score: 0.845
# Accuracy: 0.872 Recall: 0.872 Precision: 0.872 F1 Score: 0.872
# Accuracy: 0.877 Recall: 0.877 Precision: 0.877 F1 Score: 0.877
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.836 Recall: 0.836 Precision: 0.836 F1 Score: 0.836
# Accuracy: 0.847 Recall: 0.847 Precision: 0.847 F1 Score: 0.847
# Accuracy: 0.842 Recall: 0.842 Precision: 0.842 F1 Score: 0.842
# Accuracy: 0.855 Recall: 0.855 Precision: 0.855 F1 Score: 0.855
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.815 Recall: 0.815 Precision: 0.815 F1 Score: 0.815
# Frequency of hamming distance:  {0: 62.64, 1: 7.22, 2: 4.68, 3: 4.35, 4: 1.64, 5: 3.1, 6: 1.02, 7: 1.33, 8: 1.36, 9: 1.38, 10: 1.79, 11: 1.64, 12: 1.59, 13: 1.25, 14: 1.36, 15: 1.23, 16: 0.54, 17: 0.18, 18: 0.38, 19: 0.05, 20: 0.15, 21: 0.28, 22: 0.31, 23: 0.36, 24: 0.18}
# Test data percentage wrt total data: 40
# Accuracy: 0.839 Recall: 0.839 Precision: 0.839 F1 Score: 0.839
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.862 Recall: 0.862 Precision: 0.862 F1 Score: 0.862
# Accuracy: 0.857 Recall: 0.857 Precision: 0.857 F1 Score: 0.857
# Accuracy: 0.842 Recall: 0.842 Precision: 0.842 F1 Score: 0.842
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.825 Recall: 0.825 Precision: 0.825 F1 Score: 0.825
# Accuracy: 0.840 Recall: 0.840 Precision: 0.840 F1 Score: 0.840
# Accuracy: 0.837 Recall: 0.837 Precision: 0.837 F1 Score: 0.837
# Accuracy: 0.834 Recall: 0.834 Precision: 0.834 F1 Score: 0.834
# Frequency of hamming distance:  {0: 60.66, 1: 6.92, 2: 5.01, 3: 4.62, 4: 2.15, 5: 2.8, 6: 1.67, 7: 1.49, 8: 1.68, 9: 1.46, 10: 1.36, 11: 1.78, 12: 1.63, 13: 1.34, 14: 1.13, 15: 1.15, 16: 0.95, 17: 0.4, 18: 0.42, 19: 0.16, 20: 0.13, 21: 0.26, 22: 0.42, 23: 0.29, 24: 0.11}
# Test data percentage wrt total data: 50
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Accuracy: 0.825 Recall: 0.825 Precision: 0.825 F1 Score: 0.825
# Accuracy: 0.837 Recall: 0.837 Precision: 0.837 F1 Score: 0.837
# Accuracy: 0.837 Recall: 0.837 Precision: 0.837 F1 Score: 0.837
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Frequency of hamming distance:  {0: 58.73, 1: 6.93, 2: 5.32, 3: 4.18, 4: 2.46, 5: 2.77, 6: 1.85, 7: 1.92, 8: 1.5, 9: 1.55, 10: 1.93, 11: 1.66, 12: 1.98, 13: 1.37, 14: 1.24, 15: 1.25, 16: 1.06, 17: 0.41, 18: 0.47, 19: 0.24, 20: 0.28, 21: 0.17, 22: 0.28, 23: 0.25, 24: 0.22}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.851 Average Recall: 0.851 Average Precision: 0.851 Average F1 Score: 0.851
# Test percentage: 10.00 Average Accuracy: 0.870 Average Recall: 0.870 Average Precision: 0.870 Average F1 Score: 0.870
# Test percentage: 25.00 Average Accuracy: 0.844 Average Recall: 0.844 Average Precision: 0.844 Average F1 Score: 0.844
# Test percentage: 40.00 Average Accuracy: 0.841 Average Recall: 0.841 Average Precision: 0.841 Average F1 Score: 0.841
# Test percentage: 50.00 Average Accuracy: 0.833 Average Recall: 0.833 Average Precision: 0.833 Average F1 Score: 0.833
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.994 Average Recall: 0.994 Average Precision: 0.994 Average F1 Score: 0.994
# Test percentage: 10.00 Average Accuracy: 0.984 Average Recall: 0.984 Average Precision: 0.984 Average F1 Score: 0.984
# Test percentage: 25.00 Average Accuracy: 0.987 Average Recall: 0.987 Average Precision: 0.987 Average F1 Score: 0.987
# Test percentage: 40.00 Average Accuracy: 0.985 Average Recall: 0.985 Average Precision: 0.985 Average F1 Score: 0.985
# Test percentage: 50.00 Average Accuracy: 0.990 Average Recall: 0.990 Average Precision: 0.990 Average F1 Score: 0.990
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.937 Average Recall: 0.937 Average Precision: 0.937 Average F1 Score: 0.937
# Test percentage: 10.00 Average Accuracy: 0.928 Average Recall: 0.928 Average Precision: 0.928 Average F1 Score: 0.928
# Test percentage: 25.00 Average Accuracy: 0.868 Average Recall: 0.868 Average Precision: 0.868 Average F1 Score: 0.868
# Test percentage: 40.00 Average Accuracy: 0.874 Average Recall: 0.874 Average Precision: 0.874 Average F1 Score: 0.874
# Test percentage: 50.00 Average Accuracy: 0.897 Average Recall: 0.897 Average Precision: 0.897 Average F1 Score: 0.897
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.933 Average Recall: 0.933 Average Precision: 0.933 Average F1 Score: 0.933
# Test percentage: 10.00 Average Accuracy: 0.908 Average Recall: 0.908 Average Precision: 0.908 Average F1 Score: 0.908
# Test percentage: 25.00 Average Accuracy: 0.859 Average Recall: 0.859 Average Precision: 0.859 Average F1 Score: 0.859
# Test percentage: 40.00 Average Accuracy: 0.860 Average Recall: 0.860 Average Precision: 0.860 Average F1 Score: 0.860
# Test percentage: 50.00 Average Accuracy: 0.868 Average Recall: 0.868 Average Precision: 0.868 Average F1 Score: 0.868
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.549 Average Recall: 0.549 Average Precision: 0.549 Average F1 Score: 0.549
# Test percentage: 10.00 Average Accuracy: 0.757 Average Recall: 0.757 Average Precision: 0.757 Average F1 Score: 0.757
# Test percentage: 25.00 Average Accuracy: 0.839 Average Recall: 0.839 Average Precision: 0.839 Average F1 Score: 0.839
# Test percentage: 40.00 Average Accuracy: 0.831 Average Recall: 0.831 Average Precision: 0.831 Average F1 Score: 0.831
# Test percentage: 50.00 Average Accuracy: 0.821 Average Recall: 0.821 Average Precision: 0.821 Average F1 Score: 0.821
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.440 Average Recall: 0.440 Average Precision: 0.440 Average F1 Score: 0.440
# Test percentage: 10.00 Average Accuracy: 0.758 Average Recall: 0.758 Average Precision: 0.758 Average F1 Score: 0.758
# Test percentage: 25.00 Average Accuracy: 0.644 Average Recall: 0.644 Average Precision: 0.644 Average F1 Score: 0.644
# Test percentage: 40.00 Average Accuracy: 0.666 Average Recall: 0.666 Average Precision: 0.666 Average F1 Score: 0.666
# Test percentage: 50.00 Average Accuracy: 0.704 Average Recall: 0.704 Average Precision: 0.704 Average F1 Score: 0.704
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.465 Average Recall: 0.465 Average Precision: 0.465 Average F1 Score: 0.465
# Test percentage: 10.00 Average Accuracy: 0.555 Average Recall: 0.555 Average Precision: 0.555 Average F1 Score: 0.555
# Test percentage: 25.00 Average Accuracy: 0.564 Average Recall: 0.564 Average Precision: 0.564 Average F1 Score: 0.564
# Test percentage: 40.00 Average Accuracy: 0.673 Average Recall: 0.673 Average Precision: 0.673 Average F1 Score: 0.673
# Test percentage: 50.00 Average Accuracy: 0.695 Average Recall: 0.695 Average Precision: 0.695 Average F1 Score: 0.695
#
# Using mlp_sklearn classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.861 Recall: 0.861 Precision: 0.861 F1 Score: 0.861
# Accuracy: 0.890 Recall: 0.890 Precision: 0.890 F1 Score: 0.890
# Accuracy: 0.800 Recall: 0.800 Precision: 0.800 F1 Score: 0.800
# Accuracy: 0.812 Recall: 0.812 Precision: 0.812 F1 Score: 0.812
# Accuracy: 0.847 Recall: 0.847 Precision: 0.847 F1 Score: 0.847
# Accuracy: 0.857 Recall: 0.857 Precision: 0.857 F1 Score: 0.857
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.855 Recall: 0.855 Precision: 0.855 F1 Score: 0.855
# Accuracy: 0.789 Recall: 0.789 Precision: 0.789 F1 Score: 0.789
# Accuracy: 0.889 Recall: 0.889 Precision: 0.889 F1 Score: 0.889
# Frequency of hamming distance:  {0: 64.64, 1: 7.48, 2: 4.44, 3: 4.56, 4: 1.27, 5: 2.66, 6: 1.01, 7: 1.14, 8: 1.77, 9: 0.89, 10: 0.89, 11: 2.03, 12: 1.9, 13: 0.63, 14: 1.27, 15: 0.63, 16: 1.01, 17: 0.13, 18: 0.38, 20: 0.63, 21: 0.13, 22: 0.13, 24: 0.38}
# Test data percentage wrt total data: 10
# Accuracy: 0.843 Recall: 0.843 Precision: 0.843 F1 Score: 0.843
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.791 Recall: 0.791 Precision: 0.791 F1 Score: 0.791
# Accuracy: 0.807 Recall: 0.807 Precision: 0.807 F1 Score: 0.807
# Accuracy: 0.835 Recall: 0.835 Precision: 0.835 F1 Score: 0.835
# Accuracy: 0.812 Recall: 0.812 Precision: 0.812 F1 Score: 0.812
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.800 Recall: 0.800 Precision: 0.800 F1 Score: 0.800
# Accuracy: 0.884 Recall: 0.884 Precision: 0.884 F1 Score: 0.884
# Accuracy: 0.876 Recall: 0.876 Precision: 0.876 F1 Score: 0.876
# Frequency of hamming distance:  {0: 64.88, 1: 7.23, 2: 4.65, 3: 3.94, 4: 1.61, 5: 2.39, 6: 0.97, 7: 1.29, 8: 1.55, 9: 1.61, 10: 0.97, 11: 1.42, 12: 1.81, 13: 1.1, 14: 1.1, 15: 0.9, 16: 0.84, 17: 0.13, 18: 0.39, 19: 0.06, 20: 0.45, 21: 0.13, 22: 0.26, 23: 0.13, 24: 0.19}
# Test data percentage wrt total data: 25
# Accuracy: 0.862 Recall: 0.862 Precision: 0.862 F1 Score: 0.862
# Accuracy: 0.850 Recall: 0.850 Precision: 0.850 F1 Score: 0.850
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.831 Recall: 0.831 Precision: 0.831 F1 Score: 0.831
# Accuracy: 0.814 Recall: 0.814 Precision: 0.814 F1 Score: 0.814
# Accuracy: 0.811 Recall: 0.811 Precision: 0.811 F1 Score: 0.811
# Accuracy: 0.821 Recall: 0.821 Precision: 0.821 F1 Score: 0.821
# Accuracy: 0.840 Recall: 0.840 Precision: 0.840 F1 Score: 0.840
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Frequency of hamming distance:  {0: 63.75, 1: 7.34, 2: 4.59, 3: 4.25, 4: 2.01, 5: 3.11, 6: 1.13, 7: 1.32, 8: 1.11, 9: 1.48, 10: 1.08, 11: 1.45, 12: 1.58, 13: 1.29, 14: 0.98, 15: 1.29, 16: 0.74, 17: 0.29, 18: 0.18, 19: 0.13, 20: 0.24, 21: 0.03, 22: 0.13, 23: 0.26, 24: 0.24}
# Test data percentage wrt total data: 40
# Accuracy: 0.835 Recall: 0.835 Precision: 0.835 F1 Score: 0.835
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.822 Recall: 0.822 Precision: 0.822 F1 Score: 0.822
# Accuracy: 0.822 Recall: 0.822 Precision: 0.822 F1 Score: 0.822
# Accuracy: 0.808 Recall: 0.808 Precision: 0.808 F1 Score: 0.808
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.815 Recall: 0.815 Precision: 0.815 F1 Score: 0.815
# Accuracy: 0.844 Recall: 0.844 Precision: 0.844 F1 Score: 0.844
# Frequency of hamming distance:  {0: 60.82, 1: 6.69, 2: 5.17, 3: 3.95, 4: 2.12, 5: 2.9, 6: 1.63, 7: 1.95, 8: 1.59, 9: 1.48, 10: 1.69, 11: 1.64, 12: 1.5, 13: 1.48, 14: 1.14, 15: 1.11, 16: 0.98, 17: 0.44, 18: 0.49, 19: 0.1, 20: 0.21, 21: 0.2, 22: 0.28, 23: 0.26, 24: 0.2}
# Test data percentage wrt total data: 50
# Accuracy: 0.809 Recall: 0.809 Precision: 0.809 F1 Score: 0.809
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.808 Recall: 0.808 Precision: 0.808 F1 Score: 0.808
# Accuracy: 0.814 Recall: 0.814 Precision: 0.814 F1 Score: 0.814
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.794 Recall: 0.794 Precision: 0.794 F1 Score: 0.794
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.841 Recall: 0.841 Precision: 0.841 F1 Score: 0.841
# Frequency of hamming distance:  {0: 60.5, 1: 6.46, 2: 4.81, 3: 4.27, 4: 2.02, 5: 2.59, 6: 1.62, 7: 1.82, 8: 1.87, 9: 1.76, 10: 1.74, 11: 1.66, 12: 1.78, 13: 1.34, 14: 1.43, 15: 1.14, 16: 0.91, 17: 0.47, 18: 0.35, 19: 0.18, 20: 0.18, 21: 0.27, 22: 0.22, 23: 0.44, 24: 0.16, 25: 0.03}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.843 Average Recall: 0.843 Average Precision: 0.843 Average F1 Score: 0.843
# Test percentage: 10.00 Average Accuracy: 0.828 Average Recall: 0.828 Average Precision: 0.828 Average F1 Score: 0.828
# Test percentage: 25.00 Average Accuracy: 0.836 Average Recall: 0.836 Average Precision: 0.836 Average F1 Score: 0.836
# Test percentage: 40.00 Average Accuracy: 0.821 Average Recall: 0.821 Average Precision: 0.821 Average F1 Score: 0.821
# Test percentage: 50.00 Average Accuracy: 0.816 Average Recall: 0.816 Average Precision: 0.816 Average F1 Score: 0.816
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.982 Average Recall: 0.982 Average Precision: 0.982 Average F1 Score: 0.982
# Test percentage: 10.00 Average Accuracy: 0.973 Average Recall: 0.973 Average Precision: 0.973 Average F1 Score: 0.973
# Test percentage: 25.00 Average Accuracy: 0.980 Average Recall: 0.980 Average Precision: 0.980 Average F1 Score: 0.980
# Test percentage: 40.00 Average Accuracy: 0.985 Average Recall: 0.985 Average Precision: 0.985 Average F1 Score: 0.985
# Test percentage: 50.00 Average Accuracy: 0.990 Average Recall: 0.990 Average Precision: 0.990 Average F1 Score: 0.990
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.896 Average Recall: 0.896 Average Precision: 0.896 Average F1 Score: 0.896
# Test percentage: 10.00 Average Accuracy: 0.786 Average Recall: 0.786 Average Precision: 0.786 Average F1 Score: 0.786
# Test percentage: 25.00 Average Accuracy: 0.868 Average Recall: 0.868 Average Precision: 0.868 Average F1 Score: 0.868
# Test percentage: 40.00 Average Accuracy: 0.896 Average Recall: 0.896 Average Precision: 0.896 Average F1 Score: 0.896
# Test percentage: 50.00 Average Accuracy: 0.875 Average Recall: 0.875 Average Precision: 0.875 Average F1 Score: 0.875
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.867 Average Recall: 0.867 Average Precision: 0.867 Average F1 Score: 0.867
# Test percentage: 10.00 Average Accuracy: 0.808 Average Recall: 0.808 Average Precision: 0.808 Average F1 Score: 0.808
# Test percentage: 25.00 Average Accuracy: 0.873 Average Recall: 0.873 Average Precision: 0.873 Average F1 Score: 0.873
# Test percentage: 40.00 Average Accuracy: 0.827 Average Recall: 0.827 Average Precision: 0.827 Average F1 Score: 0.827
# Test percentage: 50.00 Average Accuracy: 0.843 Average Recall: 0.843 Average Precision: 0.843 Average F1 Score: 0.843
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.773 Average Recall: 0.773 Average Precision: 0.773 Average F1 Score: 0.773
# Test percentage: 10.00 Average Accuracy: 0.858 Average Recall: 0.858 Average Precision: 0.858 Average F1 Score: 0.858
# Test percentage: 25.00 Average Accuracy: 0.782 Average Recall: 0.782 Average Precision: 0.782 Average F1 Score: 0.782
# Test percentage: 40.00 Average Accuracy: 0.811 Average Recall: 0.811 Average Precision: 0.811 Average F1 Score: 0.811
# Test percentage: 50.00 Average Accuracy: 0.802 Average Recall: 0.802 Average Precision: 0.802 Average F1 Score: 0.802
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.250 Average Recall: 0.250 Average Precision: 0.250 Average F1 Score: 0.250
# Test percentage: 10.00 Average Accuracy: 0.510 Average Recall: 0.510 Average Precision: 0.510 Average F1 Score: 0.510
# Test percentage: 25.00 Average Accuracy: 0.741 Average Recall: 0.741 Average Precision: 0.741 Average F1 Score: 0.741
# Test percentage: 40.00 Average Accuracy: 0.672 Average Recall: 0.672 Average Precision: 0.672 Average F1 Score: 0.672
# Test percentage: 50.00 Average Accuracy: 0.645 Average Recall: 0.645 Average Precision: 0.645 Average F1 Score: 0.645
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.308 Average Recall: 0.308 Average Precision: 0.308 Average F1 Score: 0.308
# Test percentage: 10.00 Average Accuracy: 0.587 Average Recall: 0.587 Average Precision: 0.587 Average F1 Score: 0.587
# Test percentage: 25.00 Average Accuracy: 0.483 Average Recall: 0.483 Average Precision: 0.483 Average F1 Score: 0.483
# Test percentage: 40.00 Average Accuracy: 0.567 Average Recall: 0.567 Average Precision: 0.567 Average F1 Score: 0.567
# Test percentage: 50.00 Average Accuracy: 0.586 Average Recall: 0.586 Average Precision: 0.586 Average F1 Score: 0.586
#
# Using rand_for classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.764 Recall: 0.764 Precision: 0.764 F1 Score: 0.764
# Accuracy: 0.753 Recall: 0.753 Precision: 0.753 F1 Score: 0.753
# Accuracy: 0.806 Recall: 0.806 Precision: 0.806 F1 Score: 0.806
# Accuracy: 0.689 Recall: 0.689 Precision: 0.689 F1 Score: 0.689
# Accuracy: 0.789 Recall: 0.789 Precision: 0.789 F1 Score: 0.789
# Accuracy: 0.877 Recall: 0.877 Precision: 0.877 F1 Score: 0.877
# Accuracy: 0.810 Recall: 0.810 Precision: 0.810 F1 Score: 0.810
# Accuracy: 0.775 Recall: 0.775 Precision: 0.775 F1 Score: 0.775
# Accuracy: 0.775 Recall: 0.775 Precision: 0.775 F1 Score: 0.775
# Accuracy: 0.852 Recall: 0.852 Precision: 0.852 F1 Score: 0.852
# Frequency of hamming distance:  {0: 64.3, 1: 6.82, 2: 5.08, 3: 4.81, 4: 1.87, 5: 3.74, 6: 0.8, 7: 1.07, 8: 0.8, 9: 2.14, 10: 0.8, 11: 1.34, 12: 1.2, 13: 1.87, 14: 1.07, 15: 0.53, 16: 0.53, 17: 0.27, 18: 0.27, 20: 0.13, 21: 0.13, 22: 0.27, 23: 0.13}
# Test data percentage wrt total data: 10
# Accuracy: 0.740 Recall: 0.740 Precision: 0.740 F1 Score: 0.740
# Accuracy: 0.720 Recall: 0.720 Precision: 0.720 F1 Score: 0.720
# Accuracy: 0.797 Recall: 0.797 Precision: 0.797 F1 Score: 0.797
# Accuracy: 0.758 Recall: 0.758 Precision: 0.758 F1 Score: 0.758
# Accuracy: 0.752 Recall: 0.752 Precision: 0.752 F1 Score: 0.752
# Accuracy: 0.804 Recall: 0.804 Precision: 0.804 F1 Score: 0.804
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.801 Recall: 0.801 Precision: 0.801 F1 Score: 0.801
# Accuracy: 0.800 Recall: 0.800 Precision: 0.800 F1 Score: 0.800
# Accuracy: 0.807 Recall: 0.807 Precision: 0.807 F1 Score: 0.807
# Frequency of hamming distance:  {0: 67.38, 1: 6.89, 2: 3.88, 3: 3.81, 4: 1.74, 5: 3.28, 6: 0.74, 7: 1.54, 8: 0.87, 9: 1.14, 10: 1.4, 11: 1.47, 12: 1.14, 13: 1.34, 14: 0.94, 15: 0.87, 16: 0.67, 17: 0.2, 18: 0.27, 19: 0.07, 21: 0.07, 22: 0.13, 23: 0.07, 24: 0.13}
# Test data percentage wrt total data: 25
# Accuracy: 0.761 Recall: 0.761 Precision: 0.761 F1 Score: 0.761
# Accuracy: 0.760 Recall: 0.760 Precision: 0.760 F1 Score: 0.760
# Accuracy: 0.762 Recall: 0.762 Precision: 0.762 F1 Score: 0.762
# Accuracy: 0.800 Recall: 0.800 Precision: 0.800 F1 Score: 0.800
# Accuracy: 0.736 Recall: 0.736 Precision: 0.736 F1 Score: 0.736
# Accuracy: 0.764 Recall: 0.764 Precision: 0.764 F1 Score: 0.764
# Accuracy: 0.809 Recall: 0.809 Precision: 0.809 F1 Score: 0.809
# Accuracy: 0.777 Recall: 0.777 Precision: 0.777 F1 Score: 0.777
# Accuracy: 0.766 Recall: 0.766 Precision: 0.766 F1 Score: 0.766
# Accuracy: 0.770 Recall: 0.770 Precision: 0.770 F1 Score: 0.770
# Frequency of hamming distance:  {0: 63.91, 1: 7.15, 2: 4.55, 3: 4.04, 4: 2.05, 5: 2.1, 6: 1.41, 7: 1.49, 8: 1.41, 9: 1.3, 10: 1.3, 11: 1.73, 12: 1.65, 13: 1.36, 14: 1.06, 15: 1.14, 16: 0.64, 17: 0.32, 18: 0.4, 19: 0.08, 20: 0.21, 21: 0.08, 22: 0.32, 23: 0.21, 24: 0.08}
# Test data percentage wrt total data: 40
# Accuracy: 0.715 Recall: 0.715 Precision: 0.715 F1 Score: 0.715
# Accuracy: 0.757 Recall: 0.757 Precision: 0.757 F1 Score: 0.757
# Accuracy: 0.757 Recall: 0.757 Precision: 0.757 F1 Score: 0.757
# Accuracy: 0.731 Recall: 0.731 Precision: 0.731 F1 Score: 0.731
# Accuracy: 0.717 Recall: 0.717 Precision: 0.717 F1 Score: 0.717
# Accuracy: 0.760 Recall: 0.760 Precision: 0.760 F1 Score: 0.760
# Accuracy: 0.797 Recall: 0.797 Precision: 0.797 F1 Score: 0.797
# Accuracy: 0.785 Recall: 0.785 Precision: 0.785 F1 Score: 0.785
# Accuracy: 0.746 Recall: 0.746 Precision: 0.746 F1 Score: 0.746
# Accuracy: 0.805 Recall: 0.805 Precision: 0.805 F1 Score: 0.805
# Frequency of hamming distance:  {0: 60.21, 1: 7.33, 2: 5.25, 3: 4.51, 4: 1.86, 5: 2.94, 6: 1.59, 7: 1.93, 8: 1.59, 9: 1.37, 10: 1.72, 11: 1.33, 12: 1.73, 13: 1.29, 14: 1.01, 15: 1.24, 16: 0.98, 17: 0.39, 18: 0.51, 19: 0.29, 20: 0.1, 21: 0.19, 22: 0.22, 23: 0.27, 24: 0.14}
# Test data percentage wrt total data: 50
# Accuracy: 0.788 Recall: 0.788 Precision: 0.788 F1 Score: 0.788
# Accuracy: 0.753 Recall: 0.753 Precision: 0.753 F1 Score: 0.753
# Accuracy: 0.730 Recall: 0.730 Precision: 0.730 F1 Score: 0.730
# Accuracy: 0.777 Recall: 0.777 Precision: 0.777 F1 Score: 0.777
# Accuracy: 0.745 Recall: 0.745 Precision: 0.745 F1 Score: 0.745
# Accuracy: 0.789 Recall: 0.789 Precision: 0.789 F1 Score: 0.789
# Accuracy: 0.746 Recall: 0.746 Precision: 0.746 F1 Score: 0.746
# Accuracy: 0.766 Recall: 0.766 Precision: 0.766 F1 Score: 0.766
# Accuracy: 0.742 Recall: 0.742 Precision: 0.742 F1 Score: 0.742
# Accuracy: 0.749 Recall: 0.749 Precision: 0.749 F1 Score: 0.749
# Frequency of hamming distance:  {0: 59.22, 1: 6.53, 2: 4.88, 3: 4.47, 4: 2.31, 5: 3.04, 6: 1.85, 7: 2.01, 8: 1.57, 9: 1.61, 10: 1.52, 11: 1.86, 12: 1.82, 13: 1.28, 14: 1.48, 15: 1.19, 16: 0.94, 17: 0.55, 18: 0.46, 19: 0.21, 20: 0.14, 21: 0.25, 22: 0.29, 23: 0.39, 24: 0.12}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.789 Average Recall: 0.789 Average Precision: 0.789 Average F1 Score: 0.789
# Test percentage: 10.00 Average Accuracy: 0.782 Average Recall: 0.782 Average Precision: 0.782 Average F1 Score: 0.782
# Test percentage: 25.00 Average Accuracy: 0.771 Average Recall: 0.771 Average Precision: 0.771 Average F1 Score: 0.771
# Test percentage: 40.00 Average Accuracy: 0.757 Average Recall: 0.757 Average Precision: 0.757 Average F1 Score: 0.757
# Test percentage: 50.00 Average Accuracy: 0.758 Average Recall: 0.758 Average Precision: 0.758 Average F1 Score: 0.758
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.938 Average Recall: 0.938 Average Precision: 0.938 Average F1 Score: 0.938
# Test percentage: 10.00 Average Accuracy: 0.909 Average Recall: 0.909 Average Precision: 0.909 Average F1 Score: 0.909
# Test percentage: 25.00 Average Accuracy: 0.924 Average Recall: 0.924 Average Precision: 0.924 Average F1 Score: 0.924
# Test percentage: 40.00 Average Accuracy: 0.926 Average Recall: 0.926 Average Precision: 0.926 Average F1 Score: 0.926
# Test percentage: 50.00 Average Accuracy: 0.941 Average Recall: 0.941 Average Precision: 0.941 Average F1 Score: 0.941
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.566 Average Recall: 0.566 Average Precision: 0.566 Average F1 Score: 0.566
# Test percentage: 10.00 Average Accuracy: 0.625 Average Recall: 0.625 Average Precision: 0.625 Average F1 Score: 0.625
# Test percentage: 25.00 Average Accuracy: 0.663 Average Recall: 0.663 Average Precision: 0.663 Average F1 Score: 0.663
# Test percentage: 40.00 Average Accuracy: 0.694 Average Recall: 0.694 Average Precision: 0.694 Average F1 Score: 0.694
# Test percentage: 50.00 Average Accuracy: 0.737 Average Recall: 0.737 Average Precision: 0.737 Average F1 Score: 0.737
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.780 Average Recall: 0.780 Average Precision: 0.780 Average F1 Score: 0.780
# Test percentage: 10.00 Average Accuracy: 0.710 Average Recall: 0.710 Average Precision: 0.710 Average F1 Score: 0.710
# Test percentage: 25.00 Average Accuracy: 0.720 Average Recall: 0.720 Average Precision: 0.720 Average F1 Score: 0.720
# Test percentage: 40.00 Average Accuracy: 0.682 Average Recall: 0.682 Average Precision: 0.682 Average F1 Score: 0.682
# Test percentage: 50.00 Average Accuracy: 0.694 Average Recall: 0.694 Average Precision: 0.694 Average F1 Score: 0.694
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.755 Average Recall: 0.755 Average Precision: 0.755 Average F1 Score: 0.755
# Test percentage: 10.00 Average Accuracy: 0.706 Average Recall: 0.706 Average Precision: 0.706 Average F1 Score: 0.706
# Test percentage: 25.00 Average Accuracy: 0.646 Average Recall: 0.646 Average Precision: 0.646 Average F1 Score: 0.646
# Test percentage: 40.00 Average Accuracy: 0.658 Average Recall: 0.658 Average Precision: 0.658 Average F1 Score: 0.658
# Test percentage: 50.00 Average Accuracy: 0.654 Average Recall: 0.654 Average Precision: 0.654 Average F1 Score: 0.654
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.460 Average Recall: 0.460 Average Precision: 0.460 Average F1 Score: 0.460
# Test percentage: 10.00 Average Accuracy: 0.432 Average Recall: 0.432 Average Precision: 0.432 Average F1 Score: 0.432
# Test percentage: 25.00 Average Accuracy: 0.444 Average Recall: 0.444 Average Precision: 0.444 Average F1 Score: 0.444
# Test percentage: 40.00 Average Accuracy: 0.548 Average Recall: 0.548 Average Precision: 0.548 Average F1 Score: 0.548
# Test percentage: 50.00 Average Accuracy: 0.504 Average Recall: 0.504 Average Precision: 0.504 Average F1 Score: 0.504
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.312 Average Recall: 0.312 Average Precision: 0.312 Average F1 Score: 0.312
# Test percentage: 10.00 Average Accuracy: 0.494 Average Recall: 0.494 Average Precision: 0.494 Average F1 Score: 0.494
# Test percentage: 25.00 Average Accuracy: 0.462 Average Recall: 0.462 Average Precision: 0.462 Average F1 Score: 0.462
# Test percentage: 40.00 Average Accuracy: 0.501 Average Recall: 0.501 Average Precision: 0.501 Average F1 Score: 0.501
# Test percentage: 50.00 Average Accuracy: 0.548 Average Recall: 0.548 Average Precision: 0.548 Average F1 Score: 0.548
#
# Using dec_tree classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.890 Recall: 0.890 Precision: 0.890 F1 Score: 0.890
# Accuracy: 0.909 Recall: 0.909 Precision: 0.909 F1 Score: 0.909
# Accuracy: 0.803 Recall: 0.803 Precision: 0.803 F1 Score: 0.803
# Accuracy: 0.898 Recall: 0.898 Precision: 0.898 F1 Score: 0.898
# Accuracy: 0.902 Recall: 0.902 Precision: 0.902 F1 Score: 0.902
# Accuracy: 0.894 Recall: 0.894 Precision: 0.894 F1 Score: 0.894
# Accuracy: 0.813 Recall: 0.813 Precision: 0.813 F1 Score: 0.813
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Accuracy: 0.868 Recall: 0.868 Precision: 0.868 F1 Score: 0.868
# Accuracy: 0.812 Recall: 0.812 Precision: 0.812 F1 Score: 0.812
# Frequency of hamming distance:  {0: 68.77, 1: 3.94, 2: 3.54, 3: 5.51, 4: 1.31, 5: 3.15, 6: 1.05, 7: 2.49, 8: 1.31, 9: 0.92, 10: 0.39, 11: 1.57, 12: 1.44, 13: 0.66, 14: 1.18, 15: 0.79, 16: 0.66, 18: 0.26, 19: 0.13, 20: 0.26, 21: 0.13, 22: 0.13, 23: 0.26, 24: 0.13}
# Test data percentage wrt total data: 10
# Accuracy: 0.854 Recall: 0.854 Precision: 0.854 F1 Score: 0.854
# Accuracy: 0.811 Recall: 0.811 Precision: 0.811 F1 Score: 0.811
# Accuracy: 0.819 Recall: 0.819 Precision: 0.819 F1 Score: 0.819
# Accuracy: 0.865 Recall: 0.865 Precision: 0.865 F1 Score: 0.865
# Accuracy: 0.860 Recall: 0.860 Precision: 0.860 F1 Score: 0.860
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.865 Recall: 0.865 Precision: 0.865 F1 Score: 0.865
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Accuracy: 0.853 Recall: 0.853 Precision: 0.853 F1 Score: 0.853
# Accuracy: 0.825 Recall: 0.825 Precision: 0.825 F1 Score: 0.825
# Frequency of hamming distance:  {0: 65.01, 1: 7.13, 2: 4.44, 3: 3.7, 4: 1.75, 5: 2.56, 6: 1.01, 7: 1.28, 8: 1.35, 9: 1.01, 10: 1.08, 11: 2.42, 12: 0.94, 13: 1.14, 14: 0.81, 15: 1.21, 16: 1.21, 17: 0.34, 18: 0.13, 19: 0.34, 20: 0.27, 21: 0.07, 22: 0.27, 23: 0.4, 24: 0.13}
# Test data percentage wrt total data: 25
# Accuracy: 0.827 Recall: 0.827 Precision: 0.827 F1 Score: 0.827
# Accuracy: 0.834 Recall: 0.834 Precision: 0.834 F1 Score: 0.834
# Accuracy: 0.858 Recall: 0.858 Precision: 0.858 F1 Score: 0.858
# Accuracy: 0.827 Recall: 0.827 Precision: 0.827 F1 Score: 0.827
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Accuracy: 0.866 Recall: 0.866 Precision: 0.866 F1 Score: 0.866
# Accuracy: 0.798 Recall: 0.798 Precision: 0.798 F1 Score: 0.798
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Frequency of hamming distance:  {0: 62.88, 1: 6.86, 2: 4.66, 3: 4.9, 4: 1.69, 5: 2.99, 6: 1.16, 7: 1.67, 8: 1.43, 9: 1.3, 10: 1.3, 11: 1.67, 12: 1.48, 13: 1.32, 14: 1.24, 15: 1.03, 16: 0.64, 17: 0.29, 18: 0.32, 19: 0.19, 20: 0.26, 21: 0.08, 22: 0.21, 23: 0.26, 24: 0.16}
# Test data percentage wrt total data: 40
# Accuracy: 0.823 Recall: 0.823 Precision: 0.823 F1 Score: 0.823
# Accuracy: 0.822 Recall: 0.822 Precision: 0.822 F1 Score: 0.822
# Accuracy: 0.818 Recall: 0.818 Precision: 0.818 F1 Score: 0.818
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.843 Recall: 0.843 Precision: 0.843 F1 Score: 0.843
# ...
# Accuracy: 0.804 Recall: 0.804 Precision: 0.804 F1 Score: 0.804
# Accuracy: 0.780 Recall: 0.780 Precision: 0.780 F1 Score: 0.780
# Accuracy: 0.772 Recall: 0.772 Precision: 0.772 F1 Score: 0.772
# Accuracy: 0.777 Recall: 0.777 Precision: 0.777 F1 Score: 0.777
# Accuracy: 0.808 Recall: 0.808 Precision: 0.808 F1 Score: 0.808
# Accuracy: 0.774 Recall: 0.774 Precision: 0.774 F1 Score: 0.774
# Accuracy: 0.790 Recall: 0.790 Precision: 0.790 F1 Score: 0.790
# Accuracy: 0.776 Recall: 0.776 Precision: 0.776 F1 Score: 0.776
# Accuracy: 0.759 Recall: 0.759 Precision: 0.759 F1 Score: 0.759
# Accuracy: 0.813 Recall: 0.813 Precision: 0.813 F1 Score: 0.813
# Frequency of hamming distance:  {0: 63.28, 1: 7.01, 2: 4.67, 3: 4.44, 4: 1.99, 5: 2.58, 6: 1.34, 7: 1.5, 8: 1.42, 9: 1.37, 10: 1.16, 11: 1.91, 12: 1.5, 13: 1.03, 14: 1.11, 15: 0.72, 16: 0.75, 17: 0.49, 18: 0.44, 19: 0.15, 20: 0.26, 21: 0.15, 22: 0.26, 23: 0.34, 24: 0.15}
# Test data percentage wrt total data: 40
# Accuracy: 0.792 Recall: 0.792 Precision: 0.792 F1 Score: 0.792
# Accuracy: 0.771 Recall: 0.771 Precision: 0.771 F1 Score: 0.771
# Accuracy: 0.788 Recall: 0.788 Precision: 0.788 F1 Score: 0.788
# Accuracy: 0.782 Recall: 0.782 Precision: 0.782 F1 Score: 0.782
# Accuracy: 0.783 Recall: 0.783 Precision: 0.783 F1 Score: 0.783
# Accuracy: 0.787 Recall: 0.787 Precision: 0.787 F1 Score: 0.787
# Accuracy: 0.801 Recall: 0.801 Precision: 0.801 F1 Score: 0.801
# Accuracy: 0.766 Recall: 0.766 Precision: 0.766 F1 Score: 0.766
# Accuracy: 0.780 Recall: 0.780 Precision: 0.780 F1 Score: 0.780
# Accuracy: 0.772 Recall: 0.772 Precision: 0.772 F1 Score: 0.772
# Frequency of hamming distance:  {0: 61.01, 1: 7.05, 2: 4.92, 3: 4.04, 4: 2.26, 5: 3.08, 6: 1.4, 7: 1.73, 8: 1.27, 9: 1.45, 10: 1.6, 11: 1.86, 12: 1.76, 13: 0.96, 14: 1.52, 15: 1.25, 16: 0.93, 17: 0.37, 18: 0.36, 19: 0.11, 20: 0.21, 21: 0.24, 22: 0.16, 23: 0.29, 24: 0.15}
# Test data percentage wrt total data: 50
# Accuracy: 0.783 Recall: 0.783 Precision: 0.783 F1 Score: 0.783
# Accuracy: 0.786 Recall: 0.786 Precision: 0.786 F1 Score: 0.786
# Accuracy: 0.753 Recall: 0.753 Precision: 0.753 F1 Score: 0.753
# Accuracy: 0.788 Recall: 0.788 Precision: 0.788 F1 Score: 0.788
# Accuracy: 0.774 Recall: 0.774 Precision: 0.774 F1 Score: 0.774
# Accuracy: 0.778 Recall: 0.778 Precision: 0.778 F1 Score: 0.778
# Accuracy: 0.800 Recall: 0.800 Precision: 0.800 F1 Score: 0.800
# Accuracy: 0.775 Recall: 0.775 Precision: 0.775 F1 Score: 0.775
# Accuracy: 0.771 Recall: 0.771 Precision: 0.771 F1 Score: 0.771
# Accuracy: 0.782 Recall: 0.782 Precision: 0.782 F1 Score: 0.782
# Frequency of hamming distance:  {0: 58.66, 1: 6.58, 2: 5.03, 3: 4.33, 4: 2.56, 5: 3.04, 6: 1.67, 7: 2.08, 8: 1.73, 9: 1.56, 10: 1.77, 11: 1.49, 12: 1.81, 13: 1.41, 14: 1.45, 15: 1.38, 16: 1.06, 17: 0.65, 18: 0.35, 19: 0.32, 20: 0.17, 21: 0.18, 22: 0.28, 23: 0.27, 24: 0.16, 25: 0.04}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.779 Average Recall: 0.779 Average Precision: 0.779 Average F1 Score: 0.779
# Test percentage: 10.00 Average Accuracy: 0.791 Average Recall: 0.791 Average Precision: 0.791 Average F1 Score: 0.791
# Test percentage: 25.00 Average Accuracy: 0.785 Average Recall: 0.785 Average Precision: 0.785 Average F1 Score: 0.785
# Test percentage: 40.00 Average Accuracy: 0.782 Average Recall: 0.782 Average Precision: 0.782 Average F1 Score: 0.782
# Test percentage: 50.00 Average Accuracy: 0.779 Average Recall: 0.779 Average Precision: 0.779 Average F1 Score: 0.779
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.932 Average Recall: 0.932 Average Precision: 0.932 Average F1 Score: 0.932
# Test percentage: 10.00 Average Accuracy: 0.928 Average Recall: 0.928 Average Precision: 0.928 Average F1 Score: 0.928
# Test percentage: 25.00 Average Accuracy: 0.935 Average Recall: 0.935 Average Precision: 0.935 Average F1 Score: 0.935
# Test percentage: 40.00 Average Accuracy: 0.941 Average Recall: 0.941 Average Precision: 0.941 Average F1 Score: 0.941
# Test percentage: 50.00 Average Accuracy: 0.947 Average Recall: 0.947 Average Precision: 0.947 Average F1 Score: 0.947
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.792 Average Recall: 0.792 Average Precision: 0.792 Average F1 Score: 0.792
# Test percentage: 10.00 Average Accuracy: 0.728 Average Recall: 0.728 Average Precision: 0.728 Average F1 Score: 0.728
# Test percentage: 25.00 Average Accuracy: 0.765 Average Recall: 0.765 Average Precision: 0.765 Average F1 Score: 0.765
# Test percentage: 40.00 Average Accuracy: 0.777 Average Recall: 0.777 Average Precision: 0.777 Average F1 Score: 0.777
# Test percentage: 50.00 Average Accuracy: 0.784 Average Recall: 0.784 Average Precision: 0.784 Average F1 Score: 0.784
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.658 Average Recall: 0.658 Average Precision: 0.658 Average F1 Score: 0.658
# Test percentage: 10.00 Average Accuracy: 0.683 Average Recall: 0.683 Average Precision: 0.683 Average F1 Score: 0.683
# Test percentage: 25.00 Average Accuracy: 0.732 Average Recall: 0.732 Average Precision: 0.732 Average F1 Score: 0.732
# Test percentage: 40.00 Average Accuracy: 0.757 Average Recall: 0.757 Average Precision: 0.757 Average F1 Score: 0.757
# Test percentage: 50.00 Average Accuracy: 0.784 Average Recall: 0.784 Average Precision: 0.784 Average F1 Score: 0.784
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.545 Average Recall: 0.545 Average Precision: 0.545 Average F1 Score: 0.545
# Test percentage: 10.00 Average Accuracy: 0.739 Average Recall: 0.739 Average Precision: 0.739 Average F1 Score: 0.739
# Test percentage: 25.00 Average Accuracy: 0.691 Average Recall: 0.691 Average Precision: 0.691 Average F1 Score: 0.691
# Test percentage: 40.00 Average Accuracy: 0.703 Average Recall: 0.703 Average Precision: 0.703 Average F1 Score: 0.703
# Test percentage: 50.00 Average Accuracy: 0.685 Average Recall: 0.685 Average Precision: 0.685 Average F1 Score: 0.685
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.350 Average Recall: 0.350 Average Precision: 0.350 Average F1 Score: 0.350
# Test percentage: 10.00 Average Accuracy: 0.467 Average Recall: 0.467 Average Precision: 0.467 Average F1 Score: 0.467
# Test percentage: 25.00 Average Accuracy: 0.570 Average Recall: 0.570 Average Precision: 0.570 Average F1 Score: 0.570
# Test percentage: 40.00 Average Accuracy: 0.644 Average Recall: 0.644 Average Precision: 0.644 Average F1 Score: 0.644
# Test percentage: 50.00 Average Accuracy: 0.606 Average Recall: 0.606 Average Precision: 0.606 Average F1 Score: 0.606
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.555 Average Recall: 0.555 Average Precision: 0.555 Average F1 Score: 0.555
# Test percentage: 10.00 Average Accuracy: 0.303 Average Recall: 0.303 Average Precision: 0.303 Average F1 Score: 0.303
# Test percentage: 25.00 Average Accuracy: 0.538 Average Recall: 0.538 Average Precision: 0.538 Average F1 Score: 0.538
# Test percentage: 40.00 Average Accuracy: 0.590 Average Recall: 0.590 Average Precision: 0.590 Average F1 Score: 0.590
# Test percentage: 50.00 Average Accuracy: 0.616 Average Recall: 0.616 Average Precision: 0.616 Average F1 Score: 0.616
#
# Using ridge classifier
# Test data percentage wrt total data: 5
# Accuracy: 0.927 Recall: 0.927 Precision: 0.927 F1 Score: 0.927
# Accuracy: 0.873 Recall: 0.873 Precision: 0.873 F1 Score: 0.873
# Accuracy: 0.828 Recall: 0.828 Precision: 0.828 F1 Score: 0.828
# Accuracy: 0.883 Recall: 0.883 Precision: 0.883 F1 Score: 0.883
# Accuracy: 0.815 Recall: 0.815 Precision: 0.815 F1 Score: 0.815
# Accuracy: 0.886 Recall: 0.886 Precision: 0.886 F1 Score: 0.886
# Accuracy: 0.855 Recall: 0.855 Precision: 0.855 F1 Score: 0.855
# Accuracy: 0.843 Recall: 0.843 Precision: 0.843 F1 Score: 0.843
# Accuracy: 0.794 Recall: 0.794 Precision: 0.794 F1 Score: 0.794
# Accuracy: 0.921 Recall: 0.921 Precision: 0.921 F1 Score: 0.921
# Frequency of hamming distance:  {0: 65.55, 1: 6.28, 2: 4.41, 3: 4.01, 4: 1.6, 5: 3.47, 6: 0.4, 7: 1.47, 8: 1.07, 9: 1.07, 10: 1.47, 11: 2.8, 12: 1.47, 13: 1.34, 14: 0.8, 15: 1.34, 16: 0.53, 17: 0.13, 18: 0.13, 20: 0.13, 23: 0.53}
# Test data percentage wrt total data: 10
# Accuracy: 0.880 Recall: 0.880 Precision: 0.880 F1 Score: 0.880
# Accuracy: 0.844 Recall: 0.844 Precision: 0.844 F1 Score: 0.844
# Accuracy: 0.875 Recall: 0.875 Precision: 0.875 F1 Score: 0.875
# Accuracy: 0.863 Recall: 0.863 Precision: 0.863 F1 Score: 0.863
# Accuracy: 0.827 Recall: 0.827 Precision: 0.827 F1 Score: 0.827
# Accuracy: 0.912 Recall: 0.912 Precision: 0.912 F1 Score: 0.912
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.893 Recall: 0.893 Precision: 0.893 F1 Score: 0.893
# Accuracy: 0.858 Recall: 0.858 Precision: 0.858 F1 Score: 0.858
# Accuracy: 0.888 Recall: 0.888 Precision: 0.888 F1 Score: 0.888
# Frequency of hamming distance:  {0: 64.62, 1: 7.68, 2: 4.34, 3: 3.94, 4: 0.93, 5: 2.34, 6: 1.2, 7: 2.0, 8: 1.47, 9: 1.34, 10: 1.13, 11: 2.07, 12: 1.13, 13: 1.34, 14: 1.07, 15: 1.2, 16: 0.67, 17: 0.27, 18: 0.4, 19: 0.13, 20: 0.2, 21: 0.13, 22: 0.13, 23: 0.27}
# Test data percentage wrt total data: 25
# Accuracy: 0.869 Recall: 0.869 Precision: 0.869 F1 Score: 0.869
# Accuracy: 0.846 Recall: 0.846 Precision: 0.846 F1 Score: 0.846
# Accuracy: 0.849 Recall: 0.849 Precision: 0.849 F1 Score: 0.849
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.862 Recall: 0.862 Precision: 0.862 F1 Score: 0.862
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Accuracy: 0.853 Recall: 0.853 Precision: 0.853 F1 Score: 0.853
# Accuracy: 0.852 Recall: 0.852 Precision: 0.852 F1 Score: 0.852
# Accuracy: 0.825 Recall: 0.825 Precision: 0.825 F1 Score: 0.825
# Accuracy: 0.842 Recall: 0.842 Precision: 0.842 F1 Score: 0.842
# Frequency of hamming distance:  {0: 61.87, 1: 7.86, 2: 5.03, 3: 4.06, 4: 1.87, 5: 2.77, 6: 1.1, 7: 1.72, 8: 1.34, 9: 1.82, 10: 1.41, 11: 1.59, 12: 1.46, 13: 1.49, 14: 1.18, 15: 1.18, 16: 0.54, 17: 0.23, 18: 0.36, 19: 0.08, 20: 0.23, 21: 0.08, 22: 0.33, 23: 0.23, 24: 0.15}
# Test data percentage wrt total data: 40
# Accuracy: 0.853 Recall: 0.853 Precision: 0.853 F1 Score: 0.853
# Accuracy: 0.829 Recall: 0.829 Precision: 0.829 F1 Score: 0.829
# Accuracy: 0.851 Recall: 0.851 Precision: 0.851 F1 Score: 0.851
# Accuracy: 0.858 Recall: 0.858 Precision: 0.858 F1 Score: 0.858
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Accuracy: 0.845 Recall: 0.845 Precision: 0.845 F1 Score: 0.845
# Accuracy: 0.816 Recall: 0.816 Precision: 0.816 F1 Score: 0.816
# Accuracy: 0.863 Recall: 0.863 Precision: 0.863 F1 Score: 0.863
# Accuracy: 0.809 Recall: 0.809 Precision: 0.809 F1 Score: 0.809
# Accuracy: 0.833 Recall: 0.833 Precision: 0.833 F1 Score: 0.833
# Frequency of hamming distance:  {0: 60.23, 1: 7.0, 2: 5.16, 3: 4.28, 4: 2.24, 5: 2.69, 6: 1.52, 7: 1.71, 8: 1.63, 9: 1.44, 10: 1.76, 11: 1.91, 12: 1.6, 13: 1.29, 14: 1.32, 15: 1.06, 16: 1.0, 17: 0.46, 18: 0.41, 19: 0.13, 20: 0.18, 21: 0.28, 22: 0.2, 23: 0.31, 24: 0.21}
# Test data percentage wrt total data: 50
# Accuracy: 0.826 Recall: 0.826 Precision: 0.826 F1 Score: 0.826
# Accuracy: 0.830 Recall: 0.830 Precision: 0.830 F1 Score: 0.830
# Accuracy: 0.836 Recall: 0.836 Precision: 0.836 F1 Score: 0.836
# Accuracy: 0.806 Recall: 0.806 Precision: 0.806 F1 Score: 0.806
# Accuracy: 0.813 Recall: 0.813 Precision: 0.813 F1 Score: 0.813
# Accuracy: 0.848 Recall: 0.848 Precision: 0.848 F1 Score: 0.848
# Accuracy: 0.828 Recall: 0.828 Precision: 0.828 F1 Score: 0.828
# Accuracy: 0.844 Recall: 0.844 Precision: 0.844 F1 Score: 0.844
# Accuracy: 0.824 Recall: 0.824 Precision: 0.824 F1 Score: 0.824
# Accuracy: 0.838 Recall: 0.838 Precision: 0.838 F1 Score: 0.838
# Frequency of hamming distance:  {0: 58.71, 1: 6.42, 2: 5.77, 3: 4.25, 4: 2.38, 5: 2.96, 6: 1.65, 7: 2.0, 8: 1.56, 9: 1.64, 10: 1.85, 11: 1.56, 12: 1.85, 13: 1.23, 14: 1.35, 15: 1.12, 16: 1.09, 17: 0.58, 18: 0.4, 19: 0.27, 20: 0.19, 21: 0.25, 22: 0.31, 23: 0.42, 24: 0.17, 25: 0.01}
#
#
# Overall Stats:
# Test percentage: 5.00 Average Accuracy: 0.863 Average Recall: 0.863 Average Precision: 0.863 Average F1 Score: 0.863
# Test percentage: 10.00 Average Accuracy: 0.868 Average Recall: 0.868 Average Precision: 0.868 Average F1 Score: 0.868
# Test percentage: 25.00 Average Accuracy: 0.848 Average Recall: 0.848 Average Precision: 0.848 Average F1 Score: 0.848
# Test percentage: 40.00 Average Accuracy: 0.839 Average Recall: 0.839 Average Precision: 0.839 Average F1 Score: 0.839
# Test percentage: 50.00 Average Accuracy: 0.829 Average Recall: 0.829 Average Precision: 0.829 Average F1 Score: 0.829
#
#
# Bucket 1 Stats:
# Test percentage: 5.00 Average Accuracy: 0.988 Average Recall: 0.988 Average Precision: 0.988 Average F1 Score: 0.988
# Test percentage: 10.00 Average Accuracy: 0.989 Average Recall: 0.989 Average Precision: 0.989 Average F1 Score: 0.989
# Test percentage: 25.00 Average Accuracy: 0.988 Average Recall: 0.988 Average Precision: 0.988 Average F1 Score: 0.988
# Test percentage: 40.00 Average Accuracy: 0.989 Average Recall: 0.989 Average Precision: 0.989 Average F1 Score: 0.989
# Test percentage: 50.00 Average Accuracy: 0.990 Average Recall: 0.990 Average Precision: 0.990 Average F1 Score: 0.990
#
#
# Bucket 2 Stats:
# Test percentage: 5.00 Average Accuracy: 0.908 Average Recall: 0.908 Average Precision: 0.908 Average F1 Score: 0.908
# Test percentage: 10.00 Average Accuracy: 0.854 Average Recall: 0.854 Average Precision: 0.854 Average F1 Score: 0.854
# Test percentage: 25.00 Average Accuracy: 0.853 Average Recall: 0.853 Average Precision: 0.853 Average F1 Score: 0.853
# Test percentage: 40.00 Average Accuracy: 0.883 Average Recall: 0.883 Average Precision: 0.883 Average F1 Score: 0.883
# Test percentage: 50.00 Average Accuracy: 0.905 Average Recall: 0.905 Average Precision: 0.905 Average F1 Score: 0.905
#
#
# Bucket 3 Stats:
# Test percentage: 5.00 Average Accuracy: 0.917 Average Recall: 0.917 Average Precision: 0.917 Average F1 Score: 0.917
# Test percentage: 10.00 Average Accuracy: 0.933 Average Recall: 0.933 Average Precision: 0.933 Average F1 Score: 0.933
# Test percentage: 25.00 Average Accuracy: 0.876 Average Recall: 0.876 Average Precision: 0.876 Average F1 Score: 0.876
# Test percentage: 40.00 Average Accuracy: 0.865 Average Recall: 0.865 Average Precision: 0.865 Average F1 Score: 0.865
# Test percentage: 50.00 Average Accuracy: 0.882 Average Recall: 0.882 Average Precision: 0.882 Average F1 Score: 0.882
#
#
# Bucket 4 Stats:
# Test percentage: 5.00 Average Accuracy: 0.733 Average Recall: 0.733 Average Precision: 0.733 Average F1 Score: 0.733
# Test percentage: 10.00 Average Accuracy: 0.890 Average Recall: 0.890 Average Precision: 0.890 Average F1 Score: 0.890
# Test percentage: 25.00 Average Accuracy: 0.852 Average Recall: 0.852 Average Precision: 0.852 Average F1 Score: 0.852
# Test percentage: 40.00 Average Accuracy: 0.865 Average Recall: 0.865 Average Precision: 0.865 Average F1 Score: 0.865
# Test percentage: 50.00 Average Accuracy: 0.833 Average Recall: 0.833 Average Precision: 0.833 Average F1 Score: 0.833
#
#
# Bucket 5 Stats:
# Test percentage: 5.00 Average Accuracy: 0.408 Average Recall: 0.408 Average Precision: 0.408 Average F1 Score: 0.408
# Test percentage: 10.00 Average Accuracy: 0.500 Average Recall: 0.500 Average Precision: 0.500 Average F1 Score: 0.500
# Test percentage: 25.00 Average Accuracy: 0.778 Average Recall: 0.778 Average Precision: 0.778 Average F1 Score: 0.778
# Test percentage: 40.00 Average Accuracy: 0.773 Average Recall: 0.773 Average Precision: 0.773 Average F1 Score: 0.773
# Test percentage: 50.00 Average Accuracy: 0.771 Average Recall: 0.771 Average Precision: 0.771 Average F1 Score: 0.771
#
#
# Bucket 6 Stats:
# Test percentage: 5.00 Average Accuracy: 0.540 Average Recall: 0.540 Average Precision: 0.540 Average F1 Score: 0.540
# Test percentage: 10.00 Average Accuracy: 0.547 Average Recall: 0.547 Average Precision: 0.547 Average F1 Score: 0.547
# Test percentage: 25.00 Average Accuracy: 0.673 Average Recall: 0.673 Average Precision: 0.673 Average F1 Score: 0.673
# Test percentage: 40.00 Average Accuracy: 0.707 Average Recall: 0.707 Average Precision: 0.707 Average F1 Score: 0.707
# Test percentage: 50.00 Average Accuracy: 0.663 Average Recall: 0.663 Average Precision: 0.663 Average F1 Score: 0.663
